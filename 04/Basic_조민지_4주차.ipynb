# %% [markdown]
# # **파이썬 머신러닝 완벽 가이드(개정2판)**
# #### 권철민 저, 위키북스
# ## **04 분류**

# %% [markdown]
# ### **01 분류(Classification)의 개요**
# 지도학습의 대표적 유형
# 학습 데이터로 주어진 데이터의 피처와 레이블값을 머신러닝 알고리즘으로 학습해 모델을 생성, 모델에 새로운 데이터 값이 주어졌을 때 미지의 레이블 값을 예측하는 것
# - 베이즈 통계와 생성 모델에 기반한 **나이브 베이즈**
# - 독립변수와 종속변수의 선형 관계성에 기반한 **로지스틱 회귀**
# - 데이터 균일도에 따른 규칙 기반의 **결정 트리**
# - 개별 클래스 간의 최대 분류 마진을 효과적으로 찾아주는 **서포트 벡터 머신**
# - 근접 거리를 기준으로 하는 **최소 근접 알고리즘**
# - 심층 연결 기반의 **신경망**
# - 서로 다른 (또는 같은) 머신러닝 알고리즘을 결함한 **앙상블**

# %% [markdown]
# ### **02 결정 트리**
# #### **결정 트리 모델의 시각화**

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
import warnings
warnings.filterwarnings('ignore')

# DecisionTree Classifier 생성
dt_clf = DecisionTreeClassifier(random_state=156)

# 붓꽃 데이터를 로딩하고, 학습과 테스트 데이터셋으로 분리
iris_data = load_iris()
X_train, X_test, y_train, y_test = train_test_split(iris_data.data, iris_data.target, test_size=0.2, random_state=11)

# DecisionTreeClassifer 학습
dt_clf.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(random_state=156)

# %%
from sklearn.tree import export_graphviz

# export_graphviz()의 호출 결과로 out_file로 지정된 tree.dot 파일을 생성 
export_graphviz(dt_clf, out_file="tree.dot", class_names=iris_data.target_names,
                feature_names = iris_data.feature_names, impurity=True, filled=True)

# %%
# !pip install graphviz

import graphviz

# 위에서 생성된 tree.dot 파일을 Graphviz 읽어서 주피터 노트북 상에서 시각화 
with open("tree.dot") as f:
    dot_graph = f.read()
graphviz.Source(dot_graph)
# Out:
# Collecting graphviz
#   Downloading graphviz-0.20.3-py3-none-any.whl.metadata (12 kB)
# Downloading graphviz-0.20.3-py3-none-any.whl (47 kB)
#    ---------------------------------------- 0.0/47.1 kB ? eta -:--:--
#    -------------------------- ------------- 30.7/47.1 kB 1.4 MB/s eta 0:00:01
#    ---------------------------------------- 47.1/47.1 kB 1.2 MB/s eta 0:00:00
# Installing collected packages: graphviz
# Successfully installed graphviz-0.20.3

# %%
import seaborn as sns
import numpy as np
# %matplotlib inline

# feature importance 추출 
print("Feature importances:\n{0}".format(np.round(dt_clf.feature_importances_, 3)))

# feature별 importance 매핑
for name, value in zip(iris_data.feature_names, dt_clf.feature_importances_):
    print('{0} : {1:.3f}'.format(name, value))

# feature importance를 column별로 시각화 하기 
sns.barplot(x=dt_clf.feature_importances_, y=iris_data.feature_names)
# Out:
# Feature importances:
# [0.025 0.    0.555 0.42 ]
# sepal length (cm) : 0.025
# sepal width (cm) : 0.000
# petal length (cm) : 0.555
# petal width (cm) : 0.420
# <Axes: >

# %% [markdown]
# #### **결정 트리 과적합(Overfitting)**

# %%
from sklearn.datasets import make_classification
import matplotlib.pyplot as plt
# %matplotlib inline

plt.title("3 Class values with 2 Features Sample data creation")

# 2차원 시각화를 위해서 피처는 2개, 클래스는 3가지 유형의 clf 샘플 데이터 생성
X_features, y_labels = make_classification(n_features=2, n_redundant=0, n_informative=2,
                             n_classes=3, n_clusters_per_class=1,random_state=0)

# 그래프 형태로 2개의 피처로 2차원 좌표 시각화, 각 클래스 값은 다른 색깔로 표시됨
plt.scatter(X_features[:,0], X_features[:,1], marker='o', c=y_labels, s=25, cmap='rainbow', edgecolor='k')

# %%
import numpy as np

# Classifier의 decision boundary를 시각화하는 함수
def visualize_boundary(model, X, y):
    fig,ax = plt.subplots()
    
    # 학습 데이터 scatter plot으로 나타내기
    ax.scatter(X[:,0], X[:,1], c=y, s=25, cmap='rainbow', edgecolor='k',
               clim=(y.min(), y.max()), zorder=3)
    ax.axis('tight')
    ax.axis('off')
    xlim_start, xlim_end = ax.get_xlim()
    ylim_start, ylim_end = ax.get_ylim()
    
    # 호출 파라미터로 들어온 training 데이타로 model 학습
    model.fit(X, y)
    # meshgrid 형태인 모든 좌표값으로 예측 수행
    xx, yy = np.meshgrid(np.linspace(xlim_start,xlim_end, num=200),np.linspace(ylim_start,ylim_end, num=200))
    Z = model.predict(np.c_[xx.ravel(), yy.ravel()]).reshape(xx.shape)
    
    # contourf() 를 이용하여 class boundary 를 visualization 수행
    n_classes = len(np.unique(y))
    contours = ax.contourf(xx, yy, Z, alpha=0.3,
                           levels=np.arange(n_classes + 1) - 0.5,
                           cmap='rainbow', clim=(y.min(), y.max()),
                           zorder=1)

# %%
from sklearn.tree import DecisionTreeClassifier

# 특정한 트리 생성에 제약이 없는 decision tree의 decision boundary 시각화
dt_clf = DecisionTreeClassifier(random_state=156).fit(X_features, y_labels)
visualize_boundary(dt_clf, X_features, y_labels)

# %%
# min_samples_leaf=6으로 트리 생성 조건을 제약한 decision boundary 시각화
dt_clf = DecisionTreeClassifier(min_samples_leaf=6, random_state=156).fit(X_features, y_labels)
visualize_boundary(dt_clf, X_features, y_labels)

# %% [markdown]
# #### **결정 트리 실습 - 사용자 행동 인식 데이터 세트**

# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# features.txt 파일에는 피처 이름 index와 피처명이 공백으로 분리되어 있음. 이를 DataFrame으로 로드
feature_name_df = pd.read_csv('./human_activity/features.txt',sep='\s+', header=None,names=['column_index','column_name'])

# 피처명 index를 제거하고, 피처명만 리스트 객체로 생성한 뒤 샘플로 10개만 추출
feature_name = feature_name_df.iloc[:,1].values.tolist()
print('전체 피처명에서 10개만 추출:', feature_name[:10])
# Out:
# 전체 피처명에서 10개만 추출: ['tBodyAcc-mean()-X', 'tBodyAcc-mean()-Y', 'tBodyAcc-mean()-Z', 'tBodyAcc-std()-X', 'tBodyAcc-std()-Y', 'tBodyAcc-std()-Z', 'tBodyAcc-mad()-X', 'tBodyAcc-mad()-Y', 'tBodyAcc-mad()-Z', 'tBodyAcc-max()-X']

# %%
feature_dup_df = feature_name_df.groupby('column_name').count()
print(feature_dup_df[feature_dup_df['column_index'] > 1].count())
feature_dup_df[feature_dup_df['column_index'] > 1].head()
# Out:
# column_index    42
# dtype: int64
#                               column_index
# column_name
# fBodyAcc-bandsEnergy()-1,16              3
# fBodyAcc-bandsEnergy()-1,24              3
# fBodyAcc-bandsEnergy()-1,8               3
# fBodyAcc-bandsEnergy()-17,24             3
# fBodyAcc-bandsEnergy()-17,32             3

# %%
def get_new_feature_name_df(old_feature_name_df):
    feature_dup_df = pd.DataFrame(data=old_feature_name_df.groupby('column_name').cumcount(),
                                  columns=['dup_cnt'])
    feature_dup_df = feature_dup_df.reset_index()
    new_feature_name_df = pd.merge(old_feature_name_df.reset_index(), feature_dup_df, how='outer')
    new_feature_name_df['column_name'] = new_feature_name_df[['column_name',
                                                              'dup_cnt']].apply(lambda x : x[0]+'_'+str(x[1])
                                                                                if x[1] >0 else x[0] ,  axis=1)
    new_feature_name_df = new_feature_name_df.drop(['index'], axis=1)
    return new_feature_name_df

# %%
import pandas as pd

def get_human_dataset( ):
    
    # 각 데이터 파일들은 공백으로 분리되어 있으므로 read_csv에서 공백 문자를 sep으로 할당
    feature_name_df = pd.read_csv('./human_activity/features.txt',sep='\s+',
                        header=None,names=['column_index','column_name'])
    
    # 중복된 피처명을 수정하는 get_new_feature_name_df()를 이용, 신규 피처명 DataFrame 생성
    new_feature_name_df = get_new_feature_name_df(feature_name_df)
    
    # DataFrame에 피처명을 컬럼으로 부여하기 위해 리스트 객체로 다시 변환
    feature_name = new_feature_name_df.iloc[:, 1].values.tolist()
    
    # 학습 피처 데이터셋과 테스트 피처 데이터을 DataFrame으로 로딩. column명은 feature_name 적용
    X_train = pd.read_csv('./human_activity/train/X_train.txt',sep='\s+', names=feature_name)
    X_test = pd.read_csv('./human_activity/test/X_test.txt',sep='\s+', names=feature_name)
    
    # 학습 레이블과 테스트 레이블 데이터을 DataFrame으로 로딩하고 column명은 action으로 부여
    y_train = pd.read_csv('./human_activity/train/y_train.txt',sep='\s+',header=None,names=['action'])
    y_test = pd.read_csv('./human_activity/test/y_test.txt',sep='\s+',header=None,names=['action'])
    
    # 로드된 학습/테스트용 DataFrame을 모두 반환 
    return X_train, X_test, y_train, y_test


X_train, X_test, y_train, y_test = get_human_dataset()

# %%
print('## 학습 피처 데이터셋 info()')
print(X_train.info())
# Out:
# ## 학습 피처 데이터셋 info()
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7352 entries, 0 to 7351
# Columns: 561 entries, tBodyAcc-mean()-X to angle(Z,gravityMean)
# dtypes: float64(561)
# memory usage: 31.5 MB
# None

# %%
print(y_train['action'].value_counts())
# Out:
# action
# 6    1407
# 5    1374
# 4    1286
# 1    1226
# 2    1073
# 3     986
# Name: count, dtype: int64

# %%
from sklearn.model_selection import GridSearchCV

params = {
    'max_depth' : [6, 8, 10, 12, 16, 20, 24],
    'min_samples_split': [16]
}

grid_cv = GridSearchCV(dt_clf, param_grid=params, scoring='accuracy', cv=5, verbose=1 )
grid_cv.fit(X_train , y_train)
print('GridSearchCV 최고 평균 정확도 수치:{0:.4f}'.format(grid_cv.best_score_))
print('GridSearchCV 최적 하이퍼 파라미터:', grid_cv.best_params_)
# Out:
# Fitting 5 folds for each of 7 candidates, totalling 35 fits
# GridSearchCV 최고 평균 정확도 수치:0.8549
# GridSearchCV 최적 하이퍼 파라미터: {'max_depth': 8, 'min_samples_split': 16}

# %%
# GridSearchCV객체의 cv_results_ 속성을 DataFrame으로 생성. 
cv_results_df = pd.DataFrame(grid_cv.cv_results_)

# max_depth 파라미터 값과 그때의 테스트(Evaluation)셋, 학습 데이터 셋의 정확도 수치 추출
cv_results_df[['param_max_depth', 'mean_test_score']]
# Out:
#   param_max_depth  mean_test_score
# 0               6         0.847662
# 1               8         0.854879
# 2              10         0.852705
# 3              12         0.845768
# 4              16         0.847127
# 5              20         0.848624
# 6              24         0.848624

# %%
max_depths = [6, 8, 10, 12, 16, 20, 24]
# max_depth 값을 변화시키면서 그때마다 train과 test 데이터셋에서의 예측 성능 측정
for depth in max_depths:
    dt_clf = DecisionTreeClassifier(max_depth=depth, min_samples_split=16, random_state=156)
    dt_clf.fit(X_train , y_train)
    pred = dt_clf.predict(X_test)
    accuracy = accuracy_score(y_test , pred)
    print('max_depth = {0} 정확도: {1:.4f}'.format(depth , accuracy))
# Out:
# max_depth = 6 정확도: 0.8551
# max_depth = 8 정확도: 0.8717
# max_depth = 10 정확도: 0.8599
# max_depth = 12 정확도: 0.8571
# max_depth = 16 정확도: 0.8599
# max_depth = 20 정확도: 0.8565
# max_depth = 24 정확도: 0.8565

# %%
params = {
    'max_depth' : [8, 12, 16, 20], 
    'min_samples_split' : [16, 24],
}

grid_cv = GridSearchCV(dt_clf, param_grid=params, scoring='accuracy', cv=5, verbose=1)
grid_cv.fit(X_train, y_train)
print('GridSearchCV 최고 평균 정확도 수치: {0:.4f}'.format(grid_cv.best_score_))
print('GridSearchCV 최적 하이퍼 파라미터:', grid_cv.best_params_)
# Out:
# Fitting 5 folds for each of 8 candidates, totalling 40 fits
# GridSearchCV 최고 평균 정확도 수치: 0.8549
# GridSearchCV 최적 하이퍼 파라미터: {'max_depth': 8, 'min_samples_split': 16}

# %%
best_df_clf = grid_cv.best_estimator_
pred1 = best_df_clf.predict(X_test)
accuracy = accuracy_score(y_test, pred1)
print('결정 트리 예측 정확도:{0:.4f}'.format(accuracy))
# Out:
# 결정 트리 예측 정확도:0.8717

# %%
import seaborn as sns

ftr_importances_values = best_df_clf.feature_importances_
# Top 중요도로 정렬을 쉽게 하고, 시본(Seaborn)의 막대그래프로 쉽게 표현하기 위해 Series변환
ftr_importances = pd.Series(ftr_importances_values, index=X_train.columns  )
# 중요도값 순으로 Series를 정렬
ftr_top20 = ftr_importances.sort_values(ascending=False)[:20]
plt.figure(figsize=(8,6))
plt.title('Feature importances Top 20')
sns.barplot(x=ftr_top20, y = ftr_top20.index)
plt.show()

# %% [markdown]
# ### **03 앙상블 학습**

# %% [markdown]
# #### **보팅 분류기(Voting Classifier)**

# %%
import pandas as pd

from sklearn.ensemble import VotingClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.datasets import load_breast_cancer
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

cancer = load_breast_cancer()

data_df = pd.DataFrame(cancer.data, columns=cancer.feature_names)
data_df.head(3)
# Out:
#    mean radius  mean texture  mean perimeter  mean area  mean smoothness  \
# 0        17.99         10.38           122.8     1001.0          0.11840
# 1        20.57         17.77           132.9     1326.0          0.08474
# 2        19.69         21.25           130.0     1203.0          0.10960
#
#    mean compactness  mean concavity  mean concave points  mean symmetry  \
# 0           0.27760          0.3001              0.14710         0.2419
# 1           0.07864          0.0869              0.07017         0.1812
# 2           0.15990          0.1974              0.12790         0.2069
#
#    mean fractal dimension  ...  worst radius  worst texture  worst perimeter  \
# 0                 0.07871  ...         25.38          17.33            184.6
# 1                 0.05667  ...         24.99          23.41            158.8
# 2                 0.05999  ...         23.57          25.53            152.5
#
#    worst area  worst smoothness  worst compactness  worst concavity  \
# 0      2019.0            0.1622             0.6656           0.7119
# 1      1956.0            0.1238             0.1866           0.2416
# 2      1709.0            0.1444             0.4245           0.4504
#
#    worst concave points  worst symmetry  worst fractal dimension
# 0                0.2654          0.4601                  0.11890
# 1                0.1860          0.2750                  0.08902
# 2                0.2430          0.3613                  0.08758
#
# [3 rows x 30 columns]

# %%
# 개별 모델은 로지스틱 회귀와 KNN
lr_clf = LogisticRegression(solver='liblinear')
knn_clf = KNeighborsClassifier(n_neighbors=8)

# 개별 모델을 소프트 보팅 기반의 앙상블 모델로 구현한 분류기 
vo_clf = VotingClassifier(estimators=[('LR',lr_clf), ('KNN',knn_clf)], voting='soft')

X_train, X_test, y_train, y_test = train_test_split(cancer.data, cancer.target, test_size=0.2 , random_state= 156)

# VotingClassifier 학습/예측/평가
vo_clf.fit(X_train , y_train)
pred = vo_clf.predict(X_test)
print('Voting 분류기 정확도: {0:.4f}'.format(accuracy_score(y_test , pred)))

# 개별 모델의 학습/예측/평가
classifiers = [lr_clf, knn_clf]
for classifier in classifiers:
    classifier.fit(X_train, y_train)
    pred = classifier.predict(X_test)
    class_name= classifier.__class__.__name__
    print('{0} 정확도: {1:.4f}'.format(class_name, accuracy_score(y_test, pred)))
# Out:
# Voting 분류기 정확도: 0.9561
# LogisticRegression 정확도: 0.9474
# KNeighborsClassifier 정확도: 0.9386

# %% [markdown]
# ### **04 랜덤 포레스트**
# #### **랜덤 포레스트의 개요 및 실습**

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score
import pandas as pd
import warnings
warnings.filterwarnings('ignore')

# 결정 트리에서 사용한 get_human_dataset()을 이용해 학습/테스트용 DataFrame 반환
X_train, X_test, y_train, y_test = get_human_dataset()

# 랜덤 포레스트 학습 및 별도의 테스트 데이터셋으로 예측 성능 평가
rf_clf = RandomForestClassifier(random_state=0)
rf_clf.fit(X_train, y_train)
pred = rf_clf.predict(X_test)
accuracy = accuracy_score(y_test, pred)
print('랜덤 포레스트 정확도: {0:.4f}'.format(accuracy))
# Out:
# 랜덤 포레스트 정확도: 0.9253

# %% [markdown]
# #### **랜덤 포레스트 하이터 파라미터 및 튜닝**

# %%
from sklearn.model_selection import GridSearchCV

params = {
    'max_depth' : [8, 6, 24], 
    'min_samples_leaf' : [1, 6, 12],
    'min_samples_split' : [2, 8, 16]
}
# RandomForestClassifier 객체 생성 후 GridSearchCV 수행
rf_clf = RandomForestClassifier(random_state=0, n_jobs=-1)
grid_cv = GridSearchCV(rf_clf, param_grid=params, cv=2, n_jobs=-1)
grid_cv.fit(X_train , y_train)

print('최적 하이퍼 파라미터:\n', grid_cv.best_params_)
print('최고 예측 정확도: {0:.4f}'.format(grid_cv.best_score_))
# Out:
# 최적 하이퍼 파라미터:
#  {'max_depth': 8, 'min_samples_leaf': 1, 'min_samples_split': 2}
# 최고 예측 정확도: 0.9627

# %%
rf_clf1 = RandomForestClassifier(n_estimators=100, min_samples_leaf=6, max_depth=16, min_samples_split=2, random_state=0)

rf_clf1.fit(X_train, y_train)
pred = rf_clf1.predict(X_test)
print('예측 정확도: {0:.4f}'.format(accuracy_score(y_test, pred)))
# Out:
# 예측 정확도: 0.9260

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

ftr_importances_values = rf_clf1.feature_importances_
ftr_importances = pd.Series(ftr_importances_values, index=X_train.columns)
ftr_top20 = ftr_importances.sort_values(ascending=False)[:20]

plt.figure(figsize=(8,6))
plt.title('Feature importances Top 20')
sns.barplot(x=ftr_top20 , y=ftr_top20.index)
# Out:
# <Axes: title={'center': 'Feature importances Top 20'}>

# %% [markdown]
# ### **05 GBM(Gradient Boosting Machine)**
# #### **GBM의 개요 및 실습**

# %%
from sklearn.ensemble import GradientBoostingClassifier
import time
import warnings
warnings.filterwarnings('ignore')

X_train, X_test, y_train, y_test = get_human_dataset()

# GBM 수행 시간 측정을 위해 시작 시간 설정
start_time = time.time()

gb_clf = GradientBoostingClassifier(random_state=0)
gb_clf.fit(X_train , y_train)
gb_pred = gb_clf.predict(X_test)
gb_accuracy = accuracy_score(y_test, gb_pred)

print('GBM 정확도: {0:.4f}'.format(gb_accuracy))
print("GBM 수행 시간: {0:.1f} 초 ".format(time.time() - start_time))
# Out:
# GBM 정확도: 0.9389
# GBM 수행 시간: 1168.6 초

# %% [markdown]
# ### **06 XGBoost(eXtra Gradient Boost)**
# #### **XGBoost 설치하기**

# %%
import xgboost as xgb
from xgboost import XGBClassifier

# %% [markdown]
# #### **파이썬 래퍼 XGBoost 하이퍼 파라미터**
# - 일반 파라미터
# - 부스터 파라미터
# - 학습 태스크 파라미터

# %%
print(xgb.__version__)
# Out:
# 1.7.3

# %% [markdown]
# #### **파이썬 래퍼 XGBoost 적용 - 위스콘신 유방암 예측**

# %%
from xgboost import plot_importance
from sklearn.datasets import load_breast_cancer
from sklearn.model_selection import train_test_split
import warnings
warnings.filterwarnings('ignore')

dataset = load_breast_cancer()
X_features = dataset.data
y_label = dataset.target

cancer_df = pd.DataFrame(data=X_features, columns=dataset.feature_names)
cancer_df['target']= y_label
cancer_df.head(3)
# Out:
#    mean radius  mean texture  mean perimeter  mean area  mean smoothness  \
# 0        17.99         10.38           122.8     1001.0          0.11840
# 1        20.57         17.77           132.9     1326.0          0.08474
# 2        19.69         21.25           130.0     1203.0          0.10960
#
#    mean compactness  mean concavity  mean concave points  mean symmetry  \
# 0           0.27760          0.3001              0.14710         0.2419
# 1           0.07864          0.0869              0.07017         0.1812
# 2           0.15990          0.1974              0.12790         0.2069
#
#    mean fractal dimension  ...  worst texture  worst perimeter  worst area  \
# 0                 0.07871  ...          17.33            184.6      2019.0
# 1                 0.05667  ...          23.41            158.8      1956.0
# 2                 0.05999  ...          25.53            152.5      1709.0
#
#    worst smoothness  worst compactness  worst concavity  worst concave points  \
# 0            0.1622             0.6656           0.7119                0.2654
# 1            0.1238             0.1866           0.2416                0.1860
# 2            0.1444             0.4245           0.4504                0.2430
#
#    worst symmetry  worst fractal dimension  target
# 0          0.4601                  0.11890       0
# 1          0.2750                  0.08902       0
# 2          0.3613                  0.08758       0
#
# [3 rows x 31 columns]

# %%
print(dataset.target_names)
print(cancer_df['target'].value_counts())
# Out:
# ['malignant' 'benign']
# target
# 1    357
# 0    212
# Name: count, dtype: int64

# %%
# cancer_df에서 feature용 DataFrame과 Label용 Series 객체 추출
# 맨 마지막 칼럼이 Label임. Feature용 DataFrame은 cancer_df의 첫번째 칼럼에서
# 맨 마지막 두번째 칼럼까지를:-1 슬라이싱으로 추출
X_features = cancer_df.iloc[:, :-1]
y_label = cancer_df.iloc[:, -1]

# 전체 데이터 중 80%는 학습용 데이터, 20%는 테스트용 데이터 추출
X_train, X_test, y_train, y_test=train_test_split(X_features, y_label, test_size=0.2, random_state=156)

# 위에서 만든 X_train, y_train을 다시 쪼개서 90%는 학습과 10%는 검증용 데이터로 분리
X_tr, X_val, y_tr, y_val= train_test_split(X_train, y_train, test_size=0.1, random_state=156)
print(X_train.shape, X_test.shape)
print(X_tr.shape, X_val.shape)
# Out:
# (455, 30) (114, 30)
# (409, 30) (46, 30)

# %%
# 학습, 검증, 테스트용 DMatrix를 생성.
dtr = xgb.DMatrix(data=X_tr, label=y_tr)
dval = xgb.DMatrix(data=X_val, label=y_val)
dtest = xgb.DMatrix(data=X_test, label=y_test)

# %%
params = { 
    'max_depth':3,
    'eta': 0.05,
    'objective':'binary:logistic',
    'eval_metric':'logloss'
    }
num_rounds = 400

# %%
# 학습 데이터 셋은 'train' 또는 평가 데이터 셋은 'eval' 로 명기합니다. 
eval_list = [(dtr,'train'),(dval,'eval')] # 또는 eval_list = [(dval,'eval')]만 명기해도 무방. 

# 하이퍼 파라미터와 early stopping 파라미터를 train( ) 함수의 파라미터로 전달
xgb_model = xgb.train(params= params, dtrain=dtr, num_boost_round=num_rounds, early_stopping_rounds=50, evals=eval_list)
# Out:
# [0]	train-logloss:0.65016	eval-logloss:0.66183
# [1]	train-logloss:0.61131	eval-logloss:0.63609
# [2]	train-logloss:0.57563	eval-logloss:0.61144
# [3]	train-logloss:0.54310	eval-logloss:0.59204
# [4]	train-logloss:0.51323	eval-logloss:0.57329
# [5]	train-logloss:0.48447	eval-logloss:0.55037
# [6]	train-logloss:0.45796	eval-logloss:0.52930
# [7]	train-logloss:0.43436	eval-logloss:0.51534
# [8]	train-logloss:0.41150	eval-logloss:0.49718
# [9]	train-logloss:0.39027	eval-logloss:0.48154
# [10]	train-logloss:0.37128	eval-logloss:0.46990
# [11]	train-logloss:0.35254	eval-logloss:0.45474
# [12]	train-logloss:0.33528	eval-logloss:0.44229
# [13]	train-logloss:0.31892	eval-logloss:0.42961
# [14]	train-logloss:0.30439	eval-logloss:0.42065
# [15]	train-logloss:0.29000	eval-logloss:0.40958
# [16]	train-logloss:0.27651	eval-logloss:0.39887
# [17]	train-logloss:0.26389	eval-logloss:0.39050
# [18]	train-logloss:0.25210	eval-logloss:0.38254
# [19]	train-logloss:0.24123	eval-logloss:0.37393
# [20]	train-logloss:0.23076	eval-logloss:0.36789
# [21]	train-logloss:0.22091	eval-logloss:0.36017
# [22]	train-logloss:0.21155	eval-logloss:0.35421
# [23]	train-logloss:0.20263	eval-logloss:0.34683
# [24]	train-logloss:0.19434	eval-logloss:0.34111
# [25]	train-logloss:0.18637	eval-logloss:0.33634
# [26]	train-logloss:0.17875	eval-logloss:0.33082
# [27]	train-logloss:0.17167	eval-logloss:0.32675
# [28]	train-logloss:0.16481	eval-logloss:0.32099
# [29]	train-logloss:0.15835	eval-logloss:0.31671
# [30]	train-logloss:0.15225	eval-logloss:0.31277
# [31]	train-logloss:0.14650	eval-logloss:0.30882
# [32]	train-logloss:0.14102	eval-logloss:0.30437
# [33]	train-logloss:0.13590	eval-logloss:0.30103
# [34]	train-logloss:0.13109	eval-logloss:0.29794
# [35]	train-logloss:0.12647	eval-logloss:0.29499
# [36]	train-logloss:0.12197	eval-logloss:0.29295
# [37]	train-logloss:0.11784	eval-logloss:0.29043
# [38]	train-logloss:0.11379	eval-logloss:0.28927
# [39]	train-logloss:0.10994	eval-logloss:0.28578
# [40]	train-logloss:0.10638	eval-logloss:0.28364
# [41]	train-logloss:0.10302	eval-logloss:0.28183
# [42]	train-logloss:0.09963	eval-logloss:0.28005
# [43]	train-logloss:0.09649	eval-logloss:0.27972
# [44]	train-logloss:0.09359	eval-logloss:0.27744
# [45]	train-logloss:0.09080	eval-logloss:0.27542
# [46]	train-logloss:0.08807	eval-logloss:0.27504
# [47]	train-logloss:0.08541	eval-logloss:0.27458
# [48]	train-logloss:0.08299	eval-logloss:0.27348
# [49]	train-logloss:0.08035	eval-logloss:0.27247
# [50]	train-logloss:0.07786	eval-logloss:0.27163
# [51]	train-logloss:0.07550	eval-logloss:0.27094
# [52]	train-logloss:0.07344	eval-logloss:0.26967
# [53]	train-logloss:0.07147	eval-logloss:0.27008
# [54]	train-logloss:0.06964	eval-logloss:0.26890
# [55]	train-logloss:0.06766	eval-logloss:0.26854
# [56]	train-logloss:0.06591	eval-logloss:0.26900
# [57]	train-logloss:0.06433	eval-logloss:0.26790
# [58]	train-logloss:0.06259	eval-logloss:0.26663
# [59]	train-logloss:0.06107	eval-logloss:0.26743
# [60]	train-logloss:0.05957	eval-logloss:0.26610
# [61]	train-logloss:0.05817	eval-logloss:0.26644
# [62]	train-logloss:0.05691	eval-logloss:0.26673
# [63]	train-logloss:0.05550	eval-logloss:0.26550
# [64]	train-logloss:0.05422	eval-logloss:0.26443
# [65]	train-logloss:0.05311	eval-logloss:0.26500
# [66]	train-logloss:0.05207	eval-logloss:0.26591
# [67]	train-logloss:0.05093	eval-logloss:0.26501
# [68]	train-logloss:0.04976	eval-logloss:0.26435
# [69]	train-logloss:0.04872	eval-logloss:0.26360
# [70]	train-logloss:0.04776	eval-logloss:0.26319
# [71]	train-logloss:0.04680	eval-logloss:0.26255
# [72]	train-logloss:0.04580	eval-logloss:0.26204
# [73]	train-logloss:0.04484	eval-logloss:0.26254
# [74]	train-logloss:0.04388	eval-logloss:0.26289
# [75]	train-logloss:0.04309	eval-logloss:0.26249
# [76]	train-logloss:0.04224	eval-logloss:0.26217
# [77]	train-logloss:0.04133	eval-logloss:0.26166
# [78]	train-logloss:0.04050	eval-logloss:0.26179
# [79]	train-logloss:0.03967	eval-logloss:0.26103
# [80]	train-logloss:0.03876	eval-logloss:0.26094
# [81]	train-logloss:0.03806	eval-logloss:0.26148
# [82]	train-logloss:0.03740	eval-logloss:0.26054
# [83]	train-logloss:0.03676	eval-logloss:0.25967
# [84]	train-logloss:0.03605	eval-logloss:0.25905
# [85]	train-logloss:0.03545	eval-logloss:0.26007
# [86]	train-logloss:0.03489	eval-logloss:0.25984
# [87]	train-logloss:0.03425	eval-logloss:0.25933
# [88]	train-logloss:0.03361	eval-logloss:0.25932
# [89]	train-logloss:0.03311	eval-logloss:0.26002
# [90]	train-logloss:0.03260	eval-logloss:0.25936
# [91]	train-logloss:0.03202	eval-logloss:0.25886
# [92]	train-logloss:0.03152	eval-logloss:0.25918
# [93]	train-logloss:0.03107	eval-logloss:0.25864
# [94]	train-logloss:0.03049	eval-logloss:0.25951
# [95]	train-logloss:0.03007	eval-logloss:0.26091
# [96]	train-logloss:0.02963	eval-logloss:0.26014
# [97]	train-logloss:0.02913	eval-logloss:0.25974
# [98]	train-logloss:0.02866	eval-logloss:0.25937
# [99]	train-logloss:0.02829	eval-logloss:0.25893
# [100]	train-logloss:0.02789	eval-logloss:0.25928
# [101]	train-logloss:0.02751	eval-logloss:0.25955
# [102]	train-logloss:0.02714	eval-logloss:0.25901
# [103]	train-logloss:0.02668	eval-logloss:0.25991
# [104]	train-logloss:0.02634	eval-logloss:0.25950
# [105]	train-logloss:0.02594	eval-logloss:0.25924
# [106]	train-logloss:0.02556	eval-logloss:0.25901
# [107]	train-logloss:0.02522	eval-logloss:0.25738
# [108]	train-logloss:0.02492	eval-logloss:0.25702
# [109]	train-logloss:0.02453	eval-logloss:0.25789
# [110]	train-logloss:0.02418	eval-logloss:0.25770
# [111]	train-logloss:0.02384	eval-logloss:0.25842
# [112]	train-logloss:0.02356	eval-logloss:0.25810
# [113]	train-logloss:0.02322	eval-logloss:0.25848
# [114]	train-logloss:0.02290	eval-logloss:0.25833
# [115]	train-logloss:0.02260	eval-logloss:0.25820
# [116]	train-logloss:0.02229	eval-logloss:0.25905
# [117]	train-logloss:0.02204	eval-logloss:0.25878
# [118]	train-logloss:0.02176	eval-logloss:0.25728
# [119]	train-logloss:0.02149	eval-logloss:0.25722
# [120]	train-logloss:0.02119	eval-logloss:0.25764
# [121]	train-logloss:0.02095	eval-logloss:0.25761
# [122]	train-logloss:0.02067	eval-logloss:0.25832
# [123]	train-logloss:0.02045	eval-logloss:0.25808
# [124]	train-logloss:0.02023	eval-logloss:0.25855
# [125]	train-logloss:0.01998	eval-logloss:0.25714
# [126]	train-logloss:0.01973	eval-logloss:0.25587
# [127]	train-logloss:0.01946	eval-logloss:0.25640
# [128]	train-logloss:0.01927	eval-logloss:0.25685
# [129]	train-logloss:0.01908	eval-logloss:0.25665
# [130]	train-logloss:0.01886	eval-logloss:0.25712
# [131]	train-logloss:0.01863	eval-logloss:0.25609
# [132]	train-logloss:0.01839	eval-logloss:0.25649
# [133]	train-logloss:0.01816	eval-logloss:0.25789
# [134]	train-logloss:0.01802	eval-logloss:0.25811
# [135]	train-logloss:0.01785	eval-logloss:0.25794
# [136]	train-logloss:0.01763	eval-logloss:0.25876
# [137]	train-logloss:0.01748	eval-logloss:0.25884
# [138]	train-logloss:0.01732	eval-logloss:0.25867
# [139]	train-logloss:0.01719	eval-logloss:0.25876
# [140]	train-logloss:0.01696	eval-logloss:0.25987
# [141]	train-logloss:0.01681	eval-logloss:0.25960
# [142]	train-logloss:0.01669	eval-logloss:0.25982
# [143]	train-logloss:0.01656	eval-logloss:0.25992
# [144]	train-logloss:0.01638	eval-logloss:0.26035
# [145]	train-logloss:0.01623	eval-logloss:0.26055
# [146]	train-logloss:0.01606	eval-logloss:0.26092
# [147]	train-logloss:0.01589	eval-logloss:0.26137
# [148]	train-logloss:0.01572	eval-logloss:0.25999
# [149]	train-logloss:0.01556	eval-logloss:0.26028
# [150]	train-logloss:0.01546	eval-logloss:0.26048
# [151]	train-logloss:0.01531	eval-logloss:0.26142
# [152]	train-logloss:0.01515	eval-logloss:0.26188
# [153]	train-logloss:0.01501	eval-logloss:0.26227
# [154]	train-logloss:0.01486	eval-logloss:0.26287
# [155]	train-logloss:0.01476	eval-logloss:0.26299
# [156]	train-logloss:0.01462	eval-logloss:0.26346
# [157]	train-logloss:0.01448	eval-logloss:0.26379
# [158]	train-logloss:0.01434	eval-logloss:0.26306
# [159]	train-logloss:0.01424	eval-logloss:0.26237
# [160]	train-logloss:0.01410	eval-logloss:0.26251
# [161]	train-logloss:0.01401	eval-logloss:0.26265
# [162]	train-logloss:0.01392	eval-logloss:0.26264
# [163]	train-logloss:0.01380	eval-logloss:0.26250
# [164]	train-logloss:0.01372	eval-logloss:0.26264
# [165]	train-logloss:0.01359	eval-logloss:0.26255
# [166]	train-logloss:0.01350	eval-logloss:0.26188
# [167]	train-logloss:0.01342	eval-logloss:0.26203
# [168]	train-logloss:0.01331	eval-logloss:0.26190
# [169]	train-logloss:0.01319	eval-logloss:0.26184
# [170]	train-logloss:0.01312	eval-logloss:0.26133
# [171]	train-logloss:0.01304	eval-logloss:0.26148
# [172]	train-logloss:0.01297	eval-logloss:0.26157
# [173]	train-logloss:0.01285	eval-logloss:0.26253
# [174]	train-logloss:0.01278	eval-logloss:0.26229
# [175]	train-logloss:0.01267	eval-logloss:0.26086

# %%
pred_probs = xgb_model.predict(dtest)
print('predict( ) 수행 결과값을 10개만 표시, 예측 확률 값으로 표시됨')
print(np.round(pred_probs[:10],3))

# 예측 확률이 0.5 보다 크면 1, 그렇지 않으면 0으로 예측값 결정하여 List 객체인 preds에 저장 
preds = [ 1 if x > 0.5 else 0 for x in pred_probs ]
print('예측값 10개만 표시:',preds[:10])
# Out:
# predict( ) 수행 결과값을 10개만 표시, 예측 확률 값으로 표시됨
# [0.845 0.008 0.68  0.081 0.975 0.999 0.998 0.998 0.996 0.001]
# 예측값 10개만 표시: [1, 0, 1, 0, 1, 1, 1, 1, 1, 0]

# %%
from sklearn.metrics import confusion_matrix, accuracy_score
from sklearn.metrics import precision_score, recall_score
from sklearn.metrics import f1_score, roc_auc_score

def get_clf_eval(y_test, pred=None, pred_proba=None):
    confusion = confusion_matrix( y_test, pred)
    accuracy = accuracy_score(y_test , pred)
    precision = precision_score(y_test , pred)
    recall = recall_score(y_test , pred)
    f1 = f1_score(y_test,pred)
    # ROC-AUC 추가 
    roc_auc = roc_auc_score(y_test, pred_proba)
    print('오차 행렬')
    print(confusion)
    # ROC-AUC print 추가
    print('정확도: {0:.4f}, 정밀도: {1:.4f}, 재현율: {2:.4f},\
    F1: {3:.4f}, AUC:{4:.4f}'.format(accuracy, precision, recall, f1, roc_auc))

# %%
get_clf_eval(y_test , preds, pred_probs)
# Out:
# 오차 행렬
# [[34  3]
#  [ 2 75]]
# 정확도: 0.9561, 정밀도: 0.9615, 재현율: 0.9740,    F1: 0.9677, AUC:0.9937

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

fig, ax = plt.subplots(figsize=(10, 12))
plot_importance(xgb_model, ax=ax)
# Out:
# <Axes: title={'center': 'Feature importance'}, xlabel='F score', ylabel='Features'>

# %% [markdown]
# #### **사이킷런 래퍼 XGBoost의 개요 및 적용**

# %%
# 사이킷런 래퍼 XGBoost 클래스인 XGBClassifier 임포트
from xgboost import XGBClassifier

# Warning을 없애기 위해 eval_metric 값을 XGBClassifier 생성 인자로 입력
xgb_wrapper = XGBClassifier(n_estimators=400, learning_rate=0.1, max_depth=3, eval_metric='logloss')
xgb_wrapper.fit(X_train, y_train)
w_preds = xgb_wrapper.predict(X_test)
w_pred_proba = xgb_wrapper.predict_proba(X_test)[:, 1]

# %%
get_clf_eval(y_test , w_preds, w_pred_proba)
# Out:
# 오차 행렬
# [[35  2]
#  [ 1 76]]
# 정확도: 0.9737, 정밀도: 0.9744, 재현율: 0.9870,    F1: 0.9806, AUC:0.9951

# %%
from xgboost import XGBClassifier

xgb_wrapper = XGBClassifier(n_estimators=400, learning_rate=0.05, max_depth=3)
evals = [(X_tr, y_tr), (X_val, y_val)]
xgb_wrapper.fit(X_train, y_train, early_stopping_rounds=100, eval_metric="logloss", 
                eval_set=evals, verbose=True)

ws50_preds = xgb_wrapper.predict(X_test)
ws50_pred_proba = xgb_wrapper.predict_proba(X_test)[:, 1]
# Out:
# [0]	validation_0-logloss:0.64999	validation_1-logloss:0.65367
# [1]	validation_0-logloss:0.61080	validation_1-logloss:0.61756
# [2]	validation_0-logloss:0.57502	validation_1-logloss:0.58526
# [3]	validation_0-logloss:0.54228	validation_1-logloss:0.55571
# [4]	validation_0-logloss:0.51236	validation_1-logloss:0.53052
# [5]	validation_0-logloss:0.48462	validation_1-logloss:0.50513
# [6]	validation_0-logloss:0.45909	validation_1-logloss:0.48368
# [7]	validation_0-logloss:0.43541	validation_1-logloss:0.46345
# [8]	validation_0-logloss:0.41212	validation_1-logloss:0.44577
# [9]	validation_0-logloss:0.39154	validation_1-logloss:0.42615
# [10]	validation_0-logloss:0.37178	validation_1-logloss:0.40934
# [11]	validation_0-logloss:0.35406	validation_1-logloss:0.39311
# [12]	validation_0-logloss:0.33679	validation_1-logloss:0.37835
# [13]	validation_0-logloss:0.32068	validation_1-logloss:0.36457
# [14]	validation_0-logloss:0.30592	validation_1-logloss:0.35001
# [15]	validation_0-logloss:0.29175	validation_1-logloss:0.33783
# [16]	validation_0-logloss:0.27886	validation_1-logloss:0.32538
# [17]	validation_0-logloss:0.26634	validation_1-logloss:0.31456
# [18]	validation_0-logloss:0.25480	validation_1-logloss:0.30303
# [19]	validation_0-logloss:0.24371	validation_1-logloss:0.29340
# [20]	validation_0-logloss:0.23355	validation_1-logloss:0.28370
# [21]	validation_0-logloss:0.22371	validation_1-logloss:0.27455
# [22]	validation_0-logloss:0.21450	validation_1-logloss:0.26551
# [23]	validation_0-logloss:0.20594	validation_1-logloss:0.25716
# [24]	validation_0-logloss:0.19763	validation_1-logloss:0.24939
# [25]	validation_0-logloss:0.18978	validation_1-logloss:0.24272
# [26]	validation_0-logloss:0.18243	validation_1-logloss:0.23521
# [27]	validation_0-logloss:0.17494	validation_1-logloss:0.22942
# [28]	validation_0-logloss:0.16826	validation_1-logloss:0.22298
# [29]	validation_0-logloss:0.16205	validation_1-logloss:0.21634
# [30]	validation_0-logloss:0.15605	validation_1-logloss:0.21008
# [31]	validation_0-logloss:0.15047	validation_1-logloss:0.20412
# [32]	validation_0-logloss:0.14509	validation_1-logloss:0.19933
# [33]	validation_0-logloss:0.13993	validation_1-logloss:0.19383
# [34]	validation_0-logloss:0.13510	validation_1-logloss:0.18893
# [35]	validation_0-logloss:0.13057	validation_1-logloss:0.18401
# [36]	validation_0-logloss:0.12616	validation_1-logloss:0.17938
# [37]	validation_0-logloss:0.12186	validation_1-logloss:0.17377
# [38]	validation_0-logloss:0.11779	validation_1-logloss:0.16891
# [39]	validation_0-logloss:0.11402	validation_1-logloss:0.16518
# [40]	validation_0-logloss:0.11032	validation_1-logloss:0.16150
# [41]	validation_0-logloss:0.10659	validation_1-logloss:0.15739
# [42]	validation_0-logloss:0.10301	validation_1-logloss:0.15338
# [43]	validation_0-logloss:0.09962	validation_1-logloss:0.14871
# [44]	validation_0-logloss:0.09639	validation_1-logloss:0.14505
# [45]	validation_0-logloss:0.09348	validation_1-logloss:0.14184
# [46]	validation_0-logloss:0.09042	validation_1-logloss:0.13786
# [47]	validation_0-logloss:0.08766	validation_1-logloss:0.13470
# [48]	validation_0-logloss:0.08501	validation_1-logloss:0.13135
# [49]	validation_0-logloss:0.08250	validation_1-logloss:0.12875
# [50]	validation_0-logloss:0.08014	validation_1-logloss:0.12556
# [51]	validation_0-logloss:0.07787	validation_1-logloss:0.12318
# [52]	validation_0-logloss:0.07559	validation_1-logloss:0.11974
# [53]	validation_0-logloss:0.07337	validation_1-logloss:0.11667
# [54]	validation_0-logloss:0.07122	validation_1-logloss:0.11439
# [55]	validation_0-logloss:0.06923	validation_1-logloss:0.11132
# [56]	validation_0-logloss:0.06744	validation_1-logloss:0.10874
# [57]	validation_0-logloss:0.06569	validation_1-logloss:0.10586
# [58]	validation_0-logloss:0.06399	validation_1-logloss:0.10436
# [59]	validation_0-logloss:0.06235	validation_1-logloss:0.10220
# [60]	validation_0-logloss:0.06086	validation_1-logloss:0.10044
# [61]	validation_0-logloss:0.05922	validation_1-logloss:0.09869
# [62]	validation_0-logloss:0.05779	validation_1-logloss:0.09679
# [63]	validation_0-logloss:0.05627	validation_1-logloss:0.09518
# [64]	validation_0-logloss:0.05497	validation_1-logloss:0.09261
# [65]	validation_0-logloss:0.05376	validation_1-logloss:0.09122
# [66]	validation_0-logloss:0.05221	validation_1-logloss:0.08944
# [67]	validation_0-logloss:0.05102	validation_1-logloss:0.08785
# [68]	validation_0-logloss:0.04991	validation_1-logloss:0.08559
# [69]	validation_0-logloss:0.04870	validation_1-logloss:0.08424
# [70]	validation_0-logloss:0.04770	validation_1-logloss:0.08215
# [71]	validation_0-logloss:0.04640	validation_1-logloss:0.08072
# [72]	validation_0-logloss:0.04550	validation_1-logloss:0.07935
# [73]	validation_0-logloss:0.04450	validation_1-logloss:0.07807
# [74]	validation_0-logloss:0.04349	validation_1-logloss:0.07702
# [75]	validation_0-logloss:0.04248	validation_1-logloss:0.07498
# [76]	validation_0-logloss:0.04137	validation_1-logloss:0.07375
# [77]	validation_0-logloss:0.04052	validation_1-logloss:0.07260
# [78]	validation_0-logloss:0.03965	validation_1-logloss:0.07166
# [79]	validation_0-logloss:0.03888	validation_1-logloss:0.07044
# [80]	validation_0-logloss:0.03803	validation_1-logloss:0.06972
# [81]	validation_0-logloss:0.03727	validation_1-logloss:0.06838
# [82]	validation_0-logloss:0.03652	validation_1-logloss:0.06738
# [83]	validation_0-logloss:0.03574	validation_1-logloss:0.06560
# [84]	validation_0-logloss:0.03500	validation_1-logloss:0.06443
# [85]	validation_0-logloss:0.03434	validation_1-logloss:0.06324
# [86]	validation_0-logloss:0.03372	validation_1-logloss:0.06226
# [87]	validation_0-logloss:0.03307	validation_1-logloss:0.06179
# [88]	validation_0-logloss:0.03253	validation_1-logloss:0.06062
# [89]	validation_0-logloss:0.03199	validation_1-logloss:0.05975
# [90]	validation_0-logloss:0.03149	validation_1-logloss:0.05866
# [91]	validation_0-logloss:0.03092	validation_1-logloss:0.05804
# [92]	validation_0-logloss:0.03039	validation_1-logloss:0.05701
# [93]	validation_0-logloss:0.02980	validation_1-logloss:0.05609
# [94]	validation_0-logloss:0.02927	validation_1-logloss:0.05557
# [95]	validation_0-logloss:0.02884	validation_1-logloss:0.05460
# [96]	validation_0-logloss:0.02836	validation_1-logloss:0.05366
# [97]	validation_0-logloss:0.02789	validation_1-logloss:0.05295
# [98]	validation_0-logloss:0.02738	validation_1-logloss:0.05209
# [99]	validation_0-logloss:0.02689	validation_1-logloss:0.05132
# [100]	validation_0-logloss:0.02647	validation_1-logloss:0.05050
# [101]	validation_0-logloss:0.02610	validation_1-logloss:0.04964
# [102]	validation_0-logloss:0.02570	validation_1-logloss:0.04903
# [103]	validation_0-logloss:0.02525	validation_1-logloss:0.04826
# [104]	validation_0-logloss:0.02482	validation_1-logloss:0.04758
# [105]	validation_0-logloss:0.02446	validation_1-logloss:0.04678
# [106]	validation_0-logloss:0.02408	validation_1-logloss:0.04613
# [107]	validation_0-logloss:0.02363	validation_1-logloss:0.04564
# [108]	validation_0-logloss:0.02329	validation_1-logloss:0.04476
# [109]	validation_0-logloss:0.02296	validation_1-logloss:0.04433
# [110]	validation_0-logloss:0.02266	validation_1-logloss:0.04365
# [111]	validation_0-logloss:0.02226	validation_1-logloss:0.04321
# [112]	validation_0-logloss:0.02195	validation_1-logloss:0.04240
# [113]	validation_0-logloss:0.02165	validation_1-logloss:0.04146
# [114]	validation_0-logloss:0.02128	validation_1-logloss:0.04115
# [115]	validation_0-logloss:0.02100	validation_1-logloss:0.04028
# [116]	validation_0-logloss:0.02073	validation_1-logloss:0.03978
# [117]	validation_0-logloss:0.02040	validation_1-logloss:0.03957
# [118]	validation_0-logloss:0.02011	validation_1-logloss:0.03910
# [119]	validation_0-logloss:0.01983	validation_1-logloss:0.03864
# [120]	validation_0-logloss:0.01959	validation_1-logloss:0.03817
# [121]	validation_0-logloss:0.01931	validation_1-logloss:0.03803
# [122]	validation_0-logloss:0.01909	validation_1-logloss:0.03750
# [123]	validation_0-logloss:0.01885	validation_1-logloss:0.03681
# [124]	validation_0-logloss:0.01860	validation_1-logloss:0.03640
# [125]	validation_0-logloss:0.01836	validation_1-logloss:0.03605
# [126]	validation_0-logloss:0.01813	validation_1-logloss:0.03540
# [127]	validation_0-logloss:0.01794	validation_1-logloss:0.03494
# [128]	validation_0-logloss:0.01767	validation_1-logloss:0.03475
# [129]	validation_0-logloss:0.01746	validation_1-logloss:0.03437
# [130]	validation_0-logloss:0.01724	validation_1-logloss:0.03409
# [131]	validation_0-logloss:0.01704	validation_1-logloss:0.03343
# [132]	validation_0-logloss:0.01681	validation_1-logloss:0.03321
# [133]	validation_0-logloss:0.01663	validation_1-logloss:0.03291
# [134]	validation_0-logloss:0.01649	validation_1-logloss:0.03274
# [135]	validation_0-logloss:0.01629	validation_1-logloss:0.03241
# [136]	validation_0-logloss:0.01611	validation_1-logloss:0.03213
# [137]	validation_0-logloss:0.01598	validation_1-logloss:0.03197
# [138]	validation_0-logloss:0.01582	validation_1-logloss:0.03173
# [139]	validation_0-logloss:0.01565	validation_1-logloss:0.03146
# [140]	validation_0-logloss:0.01547	validation_1-logloss:0.03120
# [141]	validation_0-logloss:0.01532	validation_1-logloss:0.03098
# [142]	validation_0-logloss:0.01517	validation_1-logloss:0.03077
# [143]	validation_0-logloss:0.01502	validation_1-logloss:0.03056
# [144]	validation_0-logloss:0.01487	validation_1-logloss:0.03031
# [145]	validation_0-logloss:0.01471	validation_1-logloss:0.03008
# [146]	validation_0-logloss:0.01457	validation_1-logloss:0.02990
# [147]	validation_0-logloss:0.01443	validation_1-logloss:0.02956
# [148]	validation_0-logloss:0.01430	validation_1-logloss:0.02938
# [149]	validation_0-logloss:0.01414	validation_1-logloss:0.02936
# [150]	validation_0-logloss:0.01402	validation_1-logloss:0.02915
# [151]	validation_0-logloss:0.01390	validation_1-logloss:0.02898
# [152]	validation_0-logloss:0.01377	validation_1-logloss:0.02875
# [153]	validation_0-logloss:0.01364	validation_1-logloss:0.02867
# [154]	validation_0-logloss:0.01357	validation_1-logloss:0.02845
# [155]	validation_0-logloss:0.01343	validation_1-logloss:0.02841
# [156]	validation_0-logloss:0.01331	validation_1-logloss:0.02821
# [157]	validation_0-logloss:0.01320	validation_1-logloss:0.02803
# [158]	validation_0-logloss:0.01312	validation_1-logloss:0.02779
# [159]	validation_0-logloss:0.01302	validation_1-logloss:0.02774
# [160]	validation_0-logloss:0.01293	validation_1-logloss:0.02760
# [161]	validation_0-logloss:0.01281	validation_1-logloss:0.02740
# [162]	validation_0-logloss:0.01269	validation_1-logloss:0.02737
# [163]	validation_0-logloss:0.01263	validation_1-logloss:0.02717
# [164]	validation_0-logloss:0.01251	validation_1-logloss:0.02714
# [165]	validation_0-logloss:0.01240	validation_1-logloss:0.02679
# [166]	validation_0-logloss:0.01229	validation_1-logloss:0.02661
# [167]	validation_0-logloss:0.01218	validation_1-logloss:0.02657
# [168]	validation_0-logloss:0.01211	validation_1-logloss:0.02635
# [169]	validation_0-logloss:0.01203	validation_1-logloss:0.02636
# [170]	validation_0-logloss:0.01192	validation_1-logloss:0.02619
# [171]	validation_0-logloss:0.01185	validation_1-logloss:0.02607
# [172]	validation_0-logloss:0.01176	validation_1-logloss:0.02586
# [173]	validation_0-logloss:0.01167	validation_1-logloss:0.02554
# [174]	validation_0-logloss:0.01158	validation_1-logloss:0.02551
# [175]	validation_0-logloss:0.01152	validation_1-logloss:0.02537
# [176]	validation_0-logloss:0.01147	validation_1-logloss:0.02512
# [177]	validation_0-logloss:0.01140	validation_1-logloss:0.02502
# [178]	validation_0-logloss:0.01132	validation_1-logloss:0.02472
# [179]	validation_0-logloss:0.01123	validation_1-logloss:0.02464
# [180]	validation_0-logloss:0.01113	validation_1-logloss:0.02449
# [181]	validation_0-logloss:0.01105	validation_1-logloss:0.02447
# [182]	validation_0-logloss:0.01101	validation_1-logloss:0.02428
# [183]	validation_0-logloss:0.01093	validation_1-logloss:0.02400
# [184]	validation_0-logloss:0.01087	validation_1-logloss:0.02391
# [185]	validation_0-logloss:0.01078	validation_1-logloss:0.02383
# [186]	validation_0-logloss:0.01073	validation_1-logloss:0.02370
# [187]	validation_0-logloss:0.01065	validation_1-logloss:0.02363
# [188]	validation_0-logloss:0.01058	validation_1-logloss:0.02337
# [189]	validation_0-logloss:0.01051	validation_1-logloss:0.02334
# [190]	validation_0-logloss:0.01045	validation_1-logloss:0.02306
# [191]	validation_0-logloss:0.01041	validation_1-logloss:0.02289
# [192]	validation_0-logloss:0.01035	validation_1-logloss:0.02280
# [193]	validation_0-logloss:0.01030	validation_1-logloss:0.02268
# [194]	validation_0-logloss:0.01023	validation_1-logloss:0.02261
# [195]	validation_0-logloss:0.01016	validation_1-logloss:0.02237
# [196]	validation_0-logloss:0.01012	validation_1-logloss:0.02225
# [197]	validation_0-logloss:0.01006	validation_1-logloss:0.02201
# [198]	validation_0-logloss:0.01001	validation_1-logloss:0.02189
# [199]	validation_0-logloss:0.00995	validation_1-logloss:0.02183
# [200]	validation_0-logloss:0.00989	validation_1-logloss:0.02174
# [201]	validation_0-logloss:0.00985	validation_1-logloss:0.02164
# [202]	validation_0-logloss:0.00979	validation_1-logloss:0.02149
# [203]	validation_0-logloss:0.00974	validation_1-logloss:0.02127
# [204]	validation_0-logloss:0.00968	validation_1-logloss:0.02124
# [205]	validation_0-logloss:0.00965	validation_1-logloss:0.02109
# [206]	validation_0-logloss:0.00959	validation_1-logloss:0.02088
# [207]	validation_0-logloss:0.00954	validation_1-logloss:0.02087
# [208]	validation_0-logloss:0.00949	validation_1-logloss:0.02074
# [209]	validation_0-logloss:0.00944	validation_1-logloss:0.02066
# [210]	validation_0-logloss:0.00938	validation_1-logloss:0.02044
# [211]	validation_0-logloss:0.00934	validation_1-logloss:0.02034
# [212]	validation_0-logloss:0.00929	validation_1-logloss:0.02033
# [213]	validation_0-logloss:0.00923	validation_1-logloss:0.02014
# [214]	validation_0-logloss:0.00919	validation_1-logloss:0.02007
# [215]	validation_0-logloss:0.00914	validation_1-logloss:0.02001
# [216]	validation_0-logloss:0.00909	validation_1-logloss:0.01980
# [217]	validation_0-logloss:0.00905	validation_1-logloss:0.01971
# [218]	validation_0-logloss:0.00901	validation_1-logloss:0.01969
# [219]	validation_0-logloss:0.00898	validation_1-logloss:0.01955
# [220]	validation_0-logloss:0.00895	validation_1-logloss:0.01948
# [221]	validation_0-logloss:0.00891	validation_1-logloss:0.01940
# [222]	validation_0-logloss:0.00886	validation_1-logloss:0.01922
# [223]	validation_0-logloss:0.00881	validation_1-logloss:0.01922
# [224]	validation_0-logloss:0.00877	validation_1-logloss:0.01903
# [225]	validation_0-logloss:0.00872	validation_1-logloss:0.01903
# [226]	validation_0-logloss:0.00868	validation_1-logloss:0.01900
# [227]	validation_0-logloss:0.00866	validation_1-logloss:0.01887
# [228]	validation_0-logloss:0.00861	validation_1-logloss:0.01870
# [229]	validation_0-logloss:0.00857	validation_1-logloss:0.01863
# [230]	validation_0-logloss:0.00853	validation_1-logloss:0.01863
# [231]	validation_0-logloss:0.00851	validation_1-logloss:0.01860
# [232]	validation_0-logloss:0.00847	validation_1-logloss:0.01842
# [233]	validation_0-logloss:0.00843	validation_1-logloss:0.01834
# [234]	validation_0-logloss:0.00841	validation_1-logloss:0.01831
# [235]	validation_0-logloss:0.00838	validation_1-logloss:0.01825
# [236]	validation_0-logloss:0.00834	validation_1-logloss:0.01817
# [237]	validation_0-logloss:0.00831	validation_1-logloss:0.01816
# [238]	validation_0-logloss:0.00826	validation_1-logloss:0.01803
# [239]	validation_0-logloss:0.00824	validation_1-logloss:0.01790
# [240]	validation_0-logloss:0.00822	validation_1-logloss:0.01793
# [241]	validation_0-logloss:0.00818	validation_1-logloss:0.01778
# [242]	validation_0-logloss:0.00814	validation_1-logloss:0.01772
# [243]	validation_0-logloss:0.00811	validation_1-logloss:0.01764
# [244]	validation_0-logloss:0.00808	validation_1-logloss:0.01753
# [245]	validation_0-logloss:0.00805	validation_1-logloss:0.01752
# [246]	validation_0-logloss:0.00801	validation_1-logloss:0.01740
# [247]	validation_0-logloss:0.00799	validation_1-logloss:0.01729
# [248]	validation_0-logloss:0.00795	validation_1-logloss:0.01723
# [249]	validation_0-logloss:0.00792	validation_1-logloss:0.01716
# [250]	validation_0-logloss:0.00790	validation_1-logloss:0.01718
# [251]	validation_0-logloss:0.00786	validation_1-logloss:0.01703
# [252]	validation_0-logloss:0.00785	validation_1-logloss:0.01701
# [253]	validation_0-logloss:0.00783	validation_1-logloss:0.01693
# [254]	validation_0-logloss:0.00779	validation_1-logloss:0.01682
# [255]	validation_0-logloss:0.00777	validation_1-logloss:0.01684
# [256]	validation_0-logloss:0.00775	validation_1-logloss:0.01674
# [257]	validation_0-logloss:0.00771	validation_1-logloss:0.01660
# [258]	validation_0-logloss:0.00770	validation_1-logloss:0.01654
# [259]	validation_0-logloss:0.00766	validation_1-logloss:0.01655
# [260]	validation_0-logloss:0.00762	validation_1-logloss:0.01641
# [261]	validation_0-logloss:0.00760	validation_1-logloss:0.01632
# [262]	validation_0-logloss:0.00757	validation_1-logloss:0.01616
# [263]	validation_0-logloss:0.00756	validation_1-logloss:0.01611
# [264]	validation_0-logloss:0.00754	validation_1-logloss:0.01613
# [265]	validation_0-logloss:0.00752	validation_1-logloss:0.01604
# [266]	validation_0-logloss:0.00749	validation_1-logloss:0.01604
# [267]	validation_0-logloss:0.00745	validation_1-logloss:0.01594
# [268]	validation_0-logloss:0.00744	validation_1-logloss:0.01588
# [269]	validation_0-logloss:0.00742	validation_1-logloss:0.01590
# [270]	validation_0-logloss:0.00739	validation_1-logloss:0.01578
# [271]	validation_0-logloss:0.00737	validation_1-logloss:0.01570
# [272]	validation_0-logloss:0.00736	validation_1-logloss:0.01564
# [273]	validation_0-logloss:0.00733	validation_1-logloss:0.01565
# [274]	validation_0-logloss:0.00730	validation_1-logloss:0.01553
# [275]	validation_0-logloss:0.00729	validation_1-logloss:0.01551
# [276]	validation_0-logloss:0.00726	validation_1-logloss:0.01543
# [277]	validation_0-logloss:0.00724	validation_1-logloss:0.01544
# [278]	validation_0-logloss:0.00722	validation_1-logloss:0.01536
# [279]	validation_0-logloss:0.00721	validation_1-logloss:0.01531
# [280]	validation_0-logloss:0.00718	validation_1-logloss:0.01521
# [281]	validation_0-logloss:0.00717	validation_1-logloss:0.01522
# [282]	validation_0-logloss:0.00714	validation_1-logloss:0.01523
# [283]	validation_0-logloss:0.00712	validation_1-logloss:0.01515
# [284]	validation_0-logloss:0.00709	validation_1-logloss:0.01503
# [285]	validation_0-logloss:0.00708	validation_1-logloss:0.01498
# [286]	validation_0-logloss:0.00707	validation_1-logloss:0.01496
# [287]	validation_0-logloss:0.00704	validation_1-logloss:0.01489
# [288]	validation_0-logloss:0.00703	validation_1-logloss:0.01490
# [289]	validation_0-logloss:0.00701	validation_1-logloss:0.01486
# [290]	validation_0-logloss:0.00699	validation_1-logloss:0.01475
# [291]	validation_0-logloss:0.00698	validation_1-logloss:0.01470
# [292]	validation_0-logloss:0.00695	validation_1-logloss:0.01464
# [293]	validation_0-logloss:0.00694	validation_1-logloss:0.01465
# [294]	validation_0-logloss:0.00692	validation_1-logloss:0.01458
# [295]	validation_0-logloss:0.00690	validation_1-logloss:0.01447
# [296]	validation_0-logloss:0.00689	validation_1-logloss:0.01446
# [297]	validation_0-logloss:0.00688	validation_1-logloss:0.01442
# [298]	validation_0-logloss:0.00686	validation_1-logloss:0.01443
# [299]	validation_0-logloss:0.00685	validation_1-logloss:0.01440
# [300]	validation_0-logloss:0.00684	validation_1-logloss:0.01434
# [301]	validation_0-logloss:0.00683	validation_1-logloss:0.01432
# [302]	validation_0-logloss:0.00682	validation_1-logloss:0.01426
# [303]	validation_0-logloss:0.00681	validation_1-logloss:0.01423
# [304]	validation_0-logloss:0.00679	validation_1-logloss:0.01424
# [305]	validation_0-logloss:0.00679	validation_1-logloss:0.01418
# [306]	validation_0-logloss:0.00678	validation_1-logloss:0.01416
# [307]	validation_0-logloss:0.00677	validation_1-logloss:0.01412
# [308]	validation_0-logloss:0.00676	validation_1-logloss:0.01414
# [309]	validation_0-logloss:0.00675	validation_1-logloss:0.01410
# [310]	validation_0-logloss:0.00674	validation_1-logloss:0.01404
# [311]	validation_0-logloss:0.00673	validation_1-logloss:0.01403
# [312]	validation_0-logloss:0.00672	validation_1-logloss:0.01404
# [313]	validation_0-logloss:0.00671	validation_1-logloss:0.01401
# [314]	validation_0-logloss:0.00671	validation_1-logloss:0.01394
# [315]	validation_0-logloss:0.00670	validation_1-logloss:0.01393
# [316]	validation_0-logloss:0.00668	validation_1-logloss:0.01394
# [317]	validation_0-logloss:0.00667	validation_1-logloss:0.01391
# [318]	validation_0-logloss:0.00667	validation_1-logloss:0.01388
# [319]	validation_0-logloss:0.00666	validation_1-logloss:0.01381
# [320]	validation_0-logloss:0.00665	validation_1-logloss:0.01383
# [321]	validation_0-logloss:0.00664	validation_1-logloss:0.01382
# [322]	validation_0-logloss:0.00663	validation_1-logloss:0.01376
# [323]	validation_0-logloss:0.00663	validation_1-logloss:0.01373
# [324]	validation_0-logloss:0.00661	validation_1-logloss:0.01374
# [325]	validation_0-logloss:0.00661	validation_1-logloss:0.01370
# [326]	validation_0-logloss:0.00660	validation_1-logloss:0.01369
# [327]	validation_0-logloss:0.00659	validation_1-logloss:0.01366
# [328]	validation_0-logloss:0.00658	validation_1-logloss:0.01367
# [329]	validation_0-logloss:0.00657	validation_1-logloss:0.01361
# [330]	validation_0-logloss:0.00656	validation_1-logloss:0.01358
# [331]	validation_0-logloss:0.00655	validation_1-logloss:0.01358
# [332]	validation_0-logloss:0.00654	validation_1-logloss:0.01357
# [333]	validation_0-logloss:0.00654	validation_1-logloss:0.01351
# [334]	validation_0-logloss:0.00653	validation_1-logloss:0.01352
# [335]	validation_0-logloss:0.00652	validation_1-logloss:0.01351
# [336]	validation_0-logloss:0.00651	validation_1-logloss:0.01348
# [337]	validation_0-logloss:0.00650	validation_1-logloss:0.01349
# [338]	validation_0-logloss:0.00649	validation_1-logloss:0.01346
# [339]	validation_0-logloss:0.00648	validation_1-logloss:0.01343
# [340]	validation_0-logloss:0.00648	validation_1-logloss:0.01337
# [341]	validation_0-logloss:0.00647	validation_1-logloss:0.01338
# [342]	validation_0-logloss:0.00646	validation_1-logloss:0.01337
# [343]	validation_0-logloss:0.00645	validation_1-logloss:0.01337
# [344]	validation_0-logloss:0.00644	validation_1-logloss:0.01331
# [345]	validation_0-logloss:0.00644	validation_1-logloss:0.01328
# [346]	validation_0-logloss:0.00643	validation_1-logloss:0.01323
# [347]	validation_0-logloss:0.00642	validation_1-logloss:0.01321
# [348]	validation_0-logloss:0.00641	validation_1-logloss:0.01323
# [349]	validation_0-logloss:0.00640	validation_1-logloss:0.01322
# [350]	validation_0-logloss:0.00639	validation_1-logloss:0.01319
# [351]	validation_0-logloss:0.00639	validation_1-logloss:0.01316
# [352]	validation_0-logloss:0.00638	validation_1-logloss:0.01317
# [353]	validation_0-logloss:0.00637	validation_1-logloss:0.01315
# [354]	validation_0-logloss:0.00636	validation_1-logloss:0.01310
# [355]	validation_0-logloss:0.00636	validation_1-logloss:0.01307
# [356]	validation_0-logloss:0.00635	validation_1-logloss:0.01308
# [357]	validation_0-logloss:0.00634	validation_1-logloss:0.01309
# [358]	validation_0-logloss:0.00633	validation_1-logloss:0.01303
# [359]	validation_0-logloss:0.00632	validation_1-logloss:0.01302
# [360]	validation_0-logloss:0.00632	validation_1-logloss:0.01299
# [361]	validation_0-logloss:0.00631	validation_1-logloss:0.01293
# [362]	validation_0-logloss:0.00630	validation_1-logloss:0.01295
# [363]	validation_0-logloss:0.00629	validation_1-logloss:0.01292
# [364]	validation_0-logloss:0.00628	validation_1-logloss:0.01292
# [365]	validation_0-logloss:0.00627	validation_1-logloss:0.01293
# [366]	validation_0-logloss:0.00627	validation_1-logloss:0.01291
# [367]	validation_0-logloss:0.00626	validation_1-logloss:0.01288
# [368]	validation_0-logloss:0.00626	validation_1-logloss:0.01283
# [369]	validation_0-logloss:0.00625	validation_1-logloss:0.01280
# [370]	validation_0-logloss:0.00624	validation_1-logloss:0.01280
# [371]	validation_0-logloss:0.00623	validation_1-logloss:0.01279
# [372]	validation_0-logloss:0.00623	validation_1-logloss:0.01274
# [373]	validation_0-logloss:0.00622	validation_1-logloss:0.01275
# [374]	validation_0-logloss:0.00621	validation_1-logloss:0.01274
# [375]	validation_0-logloss:0.00620	validation_1-logloss:0.01271
# [376]	validation_0-logloss:0.00620	validation_1-logloss:0.01269
# [377]	validation_0-logloss:0.00619	validation_1-logloss:0.01270
# [378]	validation_0-logloss:0.00618	validation_1-logloss:0.01265
# [379]	validation_0-logloss:0.00617	validation_1-logloss:0.01263
# [380]	validation_0-logloss:0.00616	validation_1-logloss:0.01264
# [381]	validation_0-logloss:0.00616	validation_1-logloss:0.01258
# [382]	validation_0-logloss:0.00615	validation_1-logloss:0.01257
# [383]	validation_0-logloss:0.00615	validation_1-logloss:0.01254
# [384]	validation_0-logloss:0.00614	validation_1-logloss:0.01255
# [385]	validation_0-logloss:0.00613	validation_1-logloss:0.01253
# [386]	validation_0-logloss:0.00612	validation_1-logloss:0.01252
# [387]	validation_0-logloss:0.00611	validation_1-logloss:0.01253
# [388]	validation_0-logloss:0.00610	validation_1-logloss:0.01252
# [389]	validation_0-logloss:0.00610	validation_1-logloss:0.01247
# [390]	validation_0-logloss:0.00609	validation_1-logloss:0.01247
# [391]	validation_0-logloss:0.00609	validation_1-logloss:0.01244
# [392]	validation_0-logloss:0.00608	validation_1-logloss:0.01243
# [393]	validation_0-logloss:0.00607	validation_1-logloss:0.01238
# [394]	validation_0-logloss:0.00606	validation_1-logloss:0.01239
# [395]	validation_0-logloss:0.00606	validation_1-logloss:0.01239
# [396]	validation_0-logloss:0.00605	validation_1-logloss:0.01236
# [397]	validation_0-logloss:0.00604	validation_1-logloss:0.01237
# [398]	validation_0-logloss:0.00603	validation_1-logloss:0.01236
# [399]	validation_0-logloss:0.00602	validation_1-logloss:0.01236

# %%
get_clf_eval(y_test , ws50_preds, ws50_pred_proba)
# Out:
# 오차 행렬
# [[34  3]
#  [ 1 76]]
# 정확도: 0.9649, 정밀도: 0.9620, 재현율: 0.9870,    F1: 0.9744, AUC:0.9954

# %%
# early_stopping_rounds를 10으로 설정하고 재 학습. 
xgb_wrapper.fit(X_train, y_train, early_stopping_rounds=10, 
                eval_metric="logloss", eval_set=evals,verbose=True)

ws10_preds = xgb_wrapper.predict(X_test)
ws10_pred_proba = xgb_wrapper.predict_proba(X_test)[:, 1]
get_clf_eval(y_test , ws10_preds, ws10_pred_proba)
# Out:
# [0]	validation_0-logloss:0.64999	validation_1-logloss:0.65367
# [1]	validation_0-logloss:0.61080	validation_1-logloss:0.61756
# [2]	validation_0-logloss:0.57502	validation_1-logloss:0.58526
# [3]	validation_0-logloss:0.54228	validation_1-logloss:0.55571
# [4]	validation_0-logloss:0.51236	validation_1-logloss:0.53052
# [5]	validation_0-logloss:0.48462	validation_1-logloss:0.50513
# [6]	validation_0-logloss:0.45909	validation_1-logloss:0.48368
# [7]	validation_0-logloss:0.43541	validation_1-logloss:0.46345
# [8]	validation_0-logloss:0.41212	validation_1-logloss:0.44577
# [9]	validation_0-logloss:0.39154	validation_1-logloss:0.42615
# [10]	validation_0-logloss:0.37178	validation_1-logloss:0.40934
# [11]	validation_0-logloss:0.35406	validation_1-logloss:0.39311
# [12]	validation_0-logloss:0.33679	validation_1-logloss:0.37835
# [13]	validation_0-logloss:0.32068	validation_1-logloss:0.36457
# [14]	validation_0-logloss:0.30592	validation_1-logloss:0.35001
# [15]	validation_0-logloss:0.29175	validation_1-logloss:0.33783
# [16]	validation_0-logloss:0.27886	validation_1-logloss:0.32538
# [17]	validation_0-logloss:0.26634	validation_1-logloss:0.31456
# [18]	validation_0-logloss:0.25480	validation_1-logloss:0.30303
# [19]	validation_0-logloss:0.24371	validation_1-logloss:0.29340
# [20]	validation_0-logloss:0.23355	validation_1-logloss:0.28370
# [21]	validation_0-logloss:0.22371	validation_1-logloss:0.27455
# [22]	validation_0-logloss:0.21450	validation_1-logloss:0.26551
# [23]	validation_0-logloss:0.20594	validation_1-logloss:0.25716
# [24]	validation_0-logloss:0.19763	validation_1-logloss:0.24939
# [25]	validation_0-logloss:0.18978	validation_1-logloss:0.24272
# [26]	validation_0-logloss:0.18243	validation_1-logloss:0.23521
# [27]	validation_0-logloss:0.17494	validation_1-logloss:0.22942
# [28]	validation_0-logloss:0.16826	validation_1-logloss:0.22298
# [29]	validation_0-logloss:0.16205	validation_1-logloss:0.21634
# [30]	validation_0-logloss:0.15605	validation_1-logloss:0.21008
# [31]	validation_0-logloss:0.15047	validation_1-logloss:0.20412
# [32]	validation_0-logloss:0.14509	validation_1-logloss:0.19933
# [33]	validation_0-logloss:0.13993	validation_1-logloss:0.19383
# [34]	validation_0-logloss:0.13510	validation_1-logloss:0.18893
# [35]	validation_0-logloss:0.13057	validation_1-logloss:0.18401
# [36]	validation_0-logloss:0.12616	validation_1-logloss:0.17938
# [37]	validation_0-logloss:0.12186	validation_1-logloss:0.17377
# [38]	validation_0-logloss:0.11779	validation_1-logloss:0.16891
# [39]	validation_0-logloss:0.11402	validation_1-logloss:0.16518
# [40]	validation_0-logloss:0.11032	validation_1-logloss:0.16150
# [41]	validation_0-logloss:0.10659	validation_1-logloss:0.15739
# [42]	validation_0-logloss:0.10301	validation_1-logloss:0.15338
# [43]	validation_0-logloss:0.09962	validation_1-logloss:0.14871
# [44]	validation_0-logloss:0.09639	validation_1-logloss:0.14505
# [45]	validation_0-logloss:0.09348	validation_1-logloss:0.14184
# [46]	validation_0-logloss:0.09042	validation_1-logloss:0.13786
# [47]	validation_0-logloss:0.08766	validation_1-logloss:0.13470
# [48]	validation_0-logloss:0.08501	validation_1-logloss:0.13135
# [49]	validation_0-logloss:0.08250	validation_1-logloss:0.12875
# [50]	validation_0-logloss:0.08014	validation_1-logloss:0.12556
# [51]	validation_0-logloss:0.07787	validation_1-logloss:0.12318
# [52]	validation_0-logloss:0.07559	validation_1-logloss:0.11974
# [53]	validation_0-logloss:0.07337	validation_1-logloss:0.11667
# [54]	validation_0-logloss:0.07122	validation_1-logloss:0.11439
# [55]	validation_0-logloss:0.06923	validation_1-logloss:0.11132
# [56]	validation_0-logloss:0.06744	validation_1-logloss:0.10874
# [57]	validation_0-logloss:0.06569	validation_1-logloss:0.10586
# [58]	validation_0-logloss:0.06399	validation_1-logloss:0.10436
# [59]	validation_0-logloss:0.06235	validation_1-logloss:0.10220
# [60]	validation_0-logloss:0.06086	validation_1-logloss:0.10044
# [61]	validation_0-logloss:0.05922	validation_1-logloss:0.09869
# [62]	validation_0-logloss:0.05779	validation_1-logloss:0.09679
# [63]	validation_0-logloss:0.05627	validation_1-logloss:0.09518
# [64]	validation_0-logloss:0.05497	validation_1-logloss:0.09261
# [65]	validation_0-logloss:0.05376	validation_1-logloss:0.09122
# [66]	validation_0-logloss:0.05221	validation_1-logloss:0.08944
# [67]	validation_0-logloss:0.05102	validation_1-logloss:0.08785
# [68]	validation_0-logloss:0.04991	validation_1-logloss:0.08559
# [69]	validation_0-logloss:0.04870	validation_1-logloss:0.08424
# [70]	validation_0-logloss:0.04770	validation_1-logloss:0.08215
# [71]	validation_0-logloss:0.04640	validation_1-logloss:0.08072
# [72]	validation_0-logloss:0.04550	validation_1-logloss:0.07935
# [73]	validation_0-logloss:0.04450	validation_1-logloss:0.07807
# [74]	validation_0-logloss:0.04349	validation_1-logloss:0.07702
# [75]	validation_0-logloss:0.04248	validation_1-logloss:0.07498
# [76]	validation_0-logloss:0.04137	validation_1-logloss:0.07375
# [77]	validation_0-logloss:0.04052	validation_1-logloss:0.07260
# [78]	validation_0-logloss:0.03965	validation_1-logloss:0.07166
# [79]	validation_0-logloss:0.03888	validation_1-logloss:0.07044
# [80]	validation_0-logloss:0.03803	validation_1-logloss:0.06972
# [81]	validation_0-logloss:0.03727	validation_1-logloss:0.06838
# [82]	validation_0-logloss:0.03652	validation_1-logloss:0.06738
# [83]	validation_0-logloss:0.03574	validation_1-logloss:0.06560
# [84]	validation_0-logloss:0.03500	validation_1-logloss:0.06443
# [85]	validation_0-logloss:0.03434	validation_1-logloss:0.06324
# [86]	validation_0-logloss:0.03372	validation_1-logloss:0.06226
# [87]	validation_0-logloss:0.03307	validation_1-logloss:0.06179
# [88]	validation_0-logloss:0.03253	validation_1-logloss:0.06062
# [89]	validation_0-logloss:0.03199	validation_1-logloss:0.05975
# [90]	validation_0-logloss:0.03149	validation_1-logloss:0.05866
# [91]	validation_0-logloss:0.03092	validation_1-logloss:0.05804
# [92]	validation_0-logloss:0.03039	validation_1-logloss:0.05701
# [93]	validation_0-logloss:0.02980	validation_1-logloss:0.05609
# [94]	validation_0-logloss:0.02927	validation_1-logloss:0.05557
# [95]	validation_0-logloss:0.02884	validation_1-logloss:0.05460
# [96]	validation_0-logloss:0.02836	validation_1-logloss:0.05366
# [97]	validation_0-logloss:0.02789	validation_1-logloss:0.05295
# [98]	validation_0-logloss:0.02738	validation_1-logloss:0.05209
# [99]	validation_0-logloss:0.02689	validation_1-logloss:0.05132
# [100]	validation_0-logloss:0.02647	validation_1-logloss:0.05050
# [101]	validation_0-logloss:0.02610	validation_1-logloss:0.04964
# [102]	validation_0-logloss:0.02570	validation_1-logloss:0.04903
# [103]	validation_0-logloss:0.02525	validation_1-logloss:0.04826
# [104]	validation_0-logloss:0.02482	validation_1-logloss:0.04758
# [105]	validation_0-logloss:0.02446	validation_1-logloss:0.04678
# [106]	validation_0-logloss:0.02408	validation_1-logloss:0.04613
# [107]	validation_0-logloss:0.02363	validation_1-logloss:0.04564
# [108]	validation_0-logloss:0.02329	validation_1-logloss:0.04476
# [109]	validation_0-logloss:0.02296	validation_1-logloss:0.04433
# [110]	validation_0-logloss:0.02266	validation_1-logloss:0.04365
# [111]	validation_0-logloss:0.02226	validation_1-logloss:0.04321
# [112]	validation_0-logloss:0.02195	validation_1-logloss:0.04240
# [113]	validation_0-logloss:0.02165	validation_1-logloss:0.04146
# [114]	validation_0-logloss:0.02128	validation_1-logloss:0.04115
# [115]	validation_0-logloss:0.02100	validation_1-logloss:0.04028
# [116]	validation_0-logloss:0.02073	validation_1-logloss:0.03978
# [117]	validation_0-logloss:0.02040	validation_1-logloss:0.03957
# [118]	validation_0-logloss:0.02011	validation_1-logloss:0.03910
# [119]	validation_0-logloss:0.01983	validation_1-logloss:0.03864
# [120]	validation_0-logloss:0.01959	validation_1-logloss:0.03817
# [121]	validation_0-logloss:0.01931	validation_1-logloss:0.03803
# [122]	validation_0-logloss:0.01909	validation_1-logloss:0.03750
# [123]	validation_0-logloss:0.01885	validation_1-logloss:0.03681
# [124]	validation_0-logloss:0.01860	validation_1-logloss:0.03640
# [125]	validation_0-logloss:0.01836	validation_1-logloss:0.03605
# [126]	validation_0-logloss:0.01813	validation_1-logloss:0.03540
# [127]	validation_0-logloss:0.01794	validation_1-logloss:0.03494
# [128]	validation_0-logloss:0.01767	validation_1-logloss:0.03475
# [129]	validation_0-logloss:0.01746	validation_1-logloss:0.03437
# [130]	validation_0-logloss:0.01724	validation_1-logloss:0.03409
# [131]	validation_0-logloss:0.01704	validation_1-logloss:0.03343
# [132]	validation_0-logloss:0.01681	validation_1-logloss:0.03321
# [133]	validation_0-logloss:0.01663	validation_1-logloss:0.03291
# [134]	validation_0-logloss:0.01649	validation_1-logloss:0.03274
# [135]	validation_0-logloss:0.01629	validation_1-logloss:0.03241
# [136]	validation_0-logloss:0.01611	validation_1-logloss:0.03213
# [137]	validation_0-logloss:0.01598	validation_1-logloss:0.03197
# [138]	validation_0-logloss:0.01582	validation_1-logloss:0.03173
# [139]	validation_0-logloss:0.01565	validation_1-logloss:0.03146
# [140]	validation_0-logloss:0.01547	validation_1-logloss:0.03120
# [141]	validation_0-logloss:0.01532	validation_1-logloss:0.03098
# [142]	validation_0-logloss:0.01517	validation_1-logloss:0.03077
# [143]	validation_0-logloss:0.01502	validation_1-logloss:0.03056
# [144]	validation_0-logloss:0.01487	validation_1-logloss:0.03031
# [145]	validation_0-logloss:0.01471	validation_1-logloss:0.03008
# [146]	validation_0-logloss:0.01457	validation_1-logloss:0.02990
# [147]	validation_0-logloss:0.01443	validation_1-logloss:0.02956
# [148]	validation_0-logloss:0.01430	validation_1-logloss:0.02938
# [149]	validation_0-logloss:0.01414	validation_1-logloss:0.02936
# [150]	validation_0-logloss:0.01402	validation_1-logloss:0.02915
# [151]	validation_0-logloss:0.01390	validation_1-logloss:0.02898
# [152]	validation_0-logloss:0.01377	validation_1-logloss:0.02875
# [153]	validation_0-logloss:0.01364	validation_1-logloss:0.02867
# [154]	validation_0-logloss:0.01357	validation_1-logloss:0.02845
# [155]	validation_0-logloss:0.01343	validation_1-logloss:0.02841
# [156]	validation_0-logloss:0.01331	validation_1-logloss:0.02821
# [157]	validation_0-logloss:0.01320	validation_1-logloss:0.02803
# [158]	validation_0-logloss:0.01312	validation_1-logloss:0.02779
# [159]	validation_0-logloss:0.01302	validation_1-logloss:0.02774
# [160]	validation_0-logloss:0.01293	validation_1-logloss:0.02760
# [161]	validation_0-logloss:0.01281	validation_1-logloss:0.02740
# [162]	validation_0-logloss:0.01269	validation_1-logloss:0.02737
# [163]	validation_0-logloss:0.01263	validation_1-logloss:0.02717
# [164]	validation_0-logloss:0.01251	validation_1-logloss:0.02714
# [165]	validation_0-logloss:0.01240	validation_1-logloss:0.02679
# [166]	validation_0-logloss:0.01229	validation_1-logloss:0.02661
# [167]	validation_0-logloss:0.01218	validation_1-logloss:0.02657
# [168]	validation_0-logloss:0.01211	validation_1-logloss:0.02635
# [169]	validation_0-logloss:0.01203	validation_1-logloss:0.02636
# [170]	validation_0-logloss:0.01192	validation_1-logloss:0.02619
# [171]	validation_0-logloss:0.01185	validation_1-logloss:0.02607
# [172]	validation_0-logloss:0.01176	validation_1-logloss:0.02586
# [173]	validation_0-logloss:0.01167	validation_1-logloss:0.02554
# [174]	validation_0-logloss:0.01158	validation_1-logloss:0.02551
# [175]	validation_0-logloss:0.01152	validation_1-logloss:0.02537
# [176]	validation_0-logloss:0.01147	validation_1-logloss:0.02512
# [177]	validation_0-logloss:0.01140	validation_1-logloss:0.02502
# [178]	validation_0-logloss:0.01132	validation_1-logloss:0.02472
# [179]	validation_0-logloss:0.01123	validation_1-logloss:0.02464
# [180]	validation_0-logloss:0.01113	validation_1-logloss:0.02449
# [181]	validation_0-logloss:0.01105	validation_1-logloss:0.02447
# [182]	validation_0-logloss:0.01101	validation_1-logloss:0.02428
# [183]	validation_0-logloss:0.01093	validation_1-logloss:0.02400
# [184]	validation_0-logloss:0.01087	validation_1-logloss:0.02391
# [185]	validation_0-logloss:0.01078	validation_1-logloss:0.02383
# [186]	validation_0-logloss:0.01073	validation_1-logloss:0.02370
# [187]	validation_0-logloss:0.01065	validation_1-logloss:0.02363
# [188]	validation_0-logloss:0.01058	validation_1-logloss:0.02337
# [189]	validation_0-logloss:0.01051	validation_1-logloss:0.02334
# [190]	validation_0-logloss:0.01045	validation_1-logloss:0.02306
# [191]	validation_0-logloss:0.01041	validation_1-logloss:0.02289
# [192]	validation_0-logloss:0.01035	validation_1-logloss:0.02280
# [193]	validation_0-logloss:0.01030	validation_1-logloss:0.02268
# [194]	validation_0-logloss:0.01023	validation_1-logloss:0.02261
# [195]	validation_0-logloss:0.01016	validation_1-logloss:0.02237
# [196]	validation_0-logloss:0.01012	validation_1-logloss:0.02225
# [197]	validation_0-logloss:0.01006	validation_1-logloss:0.02201
# [198]	validation_0-logloss:0.01001	validation_1-logloss:0.02189
# [199]	validation_0-logloss:0.00995	validation_1-logloss:0.02183
# [200]	validation_0-logloss:0.00989	validation_1-logloss:0.02174
# [201]	validation_0-logloss:0.00985	validation_1-logloss:0.02164
# [202]	validation_0-logloss:0.00979	validation_1-logloss:0.02149
# [203]	validation_0-logloss:0.00974	validation_1-logloss:0.02127
# [204]	validation_0-logloss:0.00968	validation_1-logloss:0.02124
# [205]	validation_0-logloss:0.00965	validation_1-logloss:0.02109
# [206]	validation_0-logloss:0.00959	validation_1-logloss:0.02088
# [207]	validation_0-logloss:0.00954	validation_1-logloss:0.02087
# [208]	validation_0-logloss:0.00949	validation_1-logloss:0.02074
# [209]	validation_0-logloss:0.00944	validation_1-logloss:0.02066
# [210]	validation_0-logloss:0.00938	validation_1-logloss:0.02044
# [211]	validation_0-logloss:0.00934	validation_1-logloss:0.02034
# [212]	validation_0-logloss:0.00929	validation_1-logloss:0.02033
# [213]	validation_0-logloss:0.00923	validation_1-logloss:0.02014
# [214]	validation_0-logloss:0.00919	validation_1-logloss:0.02007
# [215]	validation_0-logloss:0.00914	validation_1-logloss:0.02001
# [216]	validation_0-logloss:0.00909	validation_1-logloss:0.01980
# [217]	validation_0-logloss:0.00905	validation_1-logloss:0.01971
# [218]	validation_0-logloss:0.00901	validation_1-logloss:0.01969
# [219]	validation_0-logloss:0.00898	validation_1-logloss:0.01955
# [220]	validation_0-logloss:0.00895	validation_1-logloss:0.01948
# [221]	validation_0-logloss:0.00891	validation_1-logloss:0.01940
# [222]	validation_0-logloss:0.00886	validation_1-logloss:0.01922
# [223]	validation_0-logloss:0.00881	validation_1-logloss:0.01922
# [224]	validation_0-logloss:0.00877	validation_1-logloss:0.01903
# [225]	validation_0-logloss:0.00872	validation_1-logloss:0.01903
# [226]	validation_0-logloss:0.00868	validation_1-logloss:0.01900
# [227]	validation_0-logloss:0.00866	validation_1-logloss:0.01887
# [228]	validation_0-logloss:0.00861	validation_1-logloss:0.01870
# [229]	validation_0-logloss:0.00857	validation_1-logloss:0.01863
# [230]	validation_0-logloss:0.00853	validation_1-logloss:0.01863
# [231]	validation_0-logloss:0.00851	validation_1-logloss:0.01860
# [232]	validation_0-logloss:0.00847	validation_1-logloss:0.01842
# [233]	validation_0-logloss:0.00843	validation_1-logloss:0.01834
# [234]	validation_0-logloss:0.00841	validation_1-logloss:0.01831
# [235]	validation_0-logloss:0.00838	validation_1-logloss:0.01825
# [236]	validation_0-logloss:0.00834	validation_1-logloss:0.01817
# [237]	validation_0-logloss:0.00831	validation_1-logloss:0.01816
# [238]	validation_0-logloss:0.00826	validation_1-logloss:0.01803
# [239]	validation_0-logloss:0.00824	validation_1-logloss:0.01790
# [240]	validation_0-logloss:0.00822	validation_1-logloss:0.01793
# [241]	validation_0-logloss:0.00818	validation_1-logloss:0.01778
# [242]	validation_0-logloss:0.00814	validation_1-logloss:0.01772
# [243]	validation_0-logloss:0.00811	validation_1-logloss:0.01764
# [244]	validation_0-logloss:0.00808	validation_1-logloss:0.01753
# [245]	validation_0-logloss:0.00805	validation_1-logloss:0.01752
# [246]	validation_0-logloss:0.00801	validation_1-logloss:0.01740
# [247]	validation_0-logloss:0.00799	validation_1-logloss:0.01729
# [248]	validation_0-logloss:0.00795	validation_1-logloss:0.01723
# [249]	validation_0-logloss:0.00792	validation_1-logloss:0.01716
# [250]	validation_0-logloss:0.00790	validation_1-logloss:0.01718
# [251]	validation_0-logloss:0.00786	validation_1-logloss:0.01703
# [252]	validation_0-logloss:0.00785	validation_1-logloss:0.01701
# [253]	validation_0-logloss:0.00783	validation_1-logloss:0.01693
# [254]	validation_0-logloss:0.00779	validation_1-logloss:0.01682
# [255]	validation_0-logloss:0.00777	validation_1-logloss:0.01684
# [256]	validation_0-logloss:0.00775	validation_1-logloss:0.01674
# [257]	validation_0-logloss:0.00771	validation_1-logloss:0.01660
# [258]	validation_0-logloss:0.00770	validation_1-logloss:0.01654
# [259]	validation_0-logloss:0.00766	validation_1-logloss:0.01655
# [260]	validation_0-logloss:0.00762	validation_1-logloss:0.01641
# [261]	validation_0-logloss:0.00760	validation_1-logloss:0.01632
# [262]	validation_0-logloss:0.00757	validation_1-logloss:0.01616
# [263]	validation_0-logloss:0.00756	validation_1-logloss:0.01611
# [264]	validation_0-logloss:0.00754	validation_1-logloss:0.01613
# [265]	validation_0-logloss:0.00752	validation_1-logloss:0.01604
# [266]	validation_0-logloss:0.00749	validation_1-logloss:0.01604
# [267]	validation_0-logloss:0.00745	validation_1-logloss:0.01594
# [268]	validation_0-logloss:0.00744	validation_1-logloss:0.01588
# [269]	validation_0-logloss:0.00742	validation_1-logloss:0.01590
# [270]	validation_0-logloss:0.00739	validation_1-logloss:0.01578
# [271]	validation_0-logloss:0.00737	validation_1-logloss:0.01570
# [272]	validation_0-logloss:0.00736	validation_1-logloss:0.01564
# [273]	validation_0-logloss:0.00733	validation_1-logloss:0.01565
# [274]	validation_0-logloss:0.00730	validation_1-logloss:0.01553
# [275]	validation_0-logloss:0.00729	validation_1-logloss:0.01551
# [276]	validation_0-logloss:0.00726	validation_1-logloss:0.01543
# [277]	validation_0-logloss:0.00724	validation_1-logloss:0.01544
# [278]	validation_0-logloss:0.00722	validation_1-logloss:0.01536
# [279]	validation_0-logloss:0.00721	validation_1-logloss:0.01531
# [280]	validation_0-logloss:0.00718	validation_1-logloss:0.01521
# [281]	validation_0-logloss:0.00717	validation_1-logloss:0.01522
# [282]	validation_0-logloss:0.00714	validation_1-logloss:0.01523
# [283]	validation_0-logloss:0.00712	validation_1-logloss:0.01515
# [284]	validation_0-logloss:0.00709	validation_1-logloss:0.01503
# [285]	validation_0-logloss:0.00708	validation_1-logloss:0.01498
# [286]	validation_0-logloss:0.00707	validation_1-logloss:0.01496
# [287]	validation_0-logloss:0.00704	validation_1-logloss:0.01489
# [288]	validation_0-logloss:0.00703	validation_1-logloss:0.01490
# [289]	validation_0-logloss:0.00701	validation_1-logloss:0.01486
# [290]	validation_0-logloss:0.00699	validation_1-logloss:0.01475
# [291]	validation_0-logloss:0.00698	validation_1-logloss:0.01470
# [292]	validation_0-logloss:0.00695	validation_1-logloss:0.01464
# [293]	validation_0-logloss:0.00694	validation_1-logloss:0.01465
# [294]	validation_0-logloss:0.00692	validation_1-logloss:0.01458
# [295]	validation_0-logloss:0.00690	validation_1-logloss:0.01447
# [296]	validation_0-logloss:0.00689	validation_1-logloss:0.01446
# [297]	validation_0-logloss:0.00688	validation_1-logloss:0.01442
# [298]	validation_0-logloss:0.00686	validation_1-logloss:0.01443
# [299]	validation_0-logloss:0.00685	validation_1-logloss:0.01440
# [300]	validation_0-logloss:0.00684	validation_1-logloss:0.01434
# [301]	validation_0-logloss:0.00683	validation_1-logloss:0.01432
# [302]	validation_0-logloss:0.00682	validation_1-logloss:0.01426
# [303]	validation_0-logloss:0.00681	validation_1-logloss:0.01423
# [304]	validation_0-logloss:0.00679	validation_1-logloss:0.01424
# [305]	validation_0-logloss:0.00679	validation_1-logloss:0.01418
# [306]	validation_0-logloss:0.00678	validation_1-logloss:0.01416
# [307]	validation_0-logloss:0.00677	validation_1-logloss:0.01412
# [308]	validation_0-logloss:0.00676	validation_1-logloss:0.01414
# [309]	validation_0-logloss:0.00675	validation_1-logloss:0.01410
# [310]	validation_0-logloss:0.00674	validation_1-logloss:0.01404
# [311]	validation_0-logloss:0.00673	validation_1-logloss:0.01403
# [312]	validation_0-logloss:0.00672	validation_1-logloss:0.01404
# [313]	validation_0-logloss:0.00671	validation_1-logloss:0.01401
# [314]	validation_0-logloss:0.00671	validation_1-logloss:0.01394
# [315]	validation_0-logloss:0.00670	validation_1-logloss:0.01393
# [316]	validation_0-logloss:0.00668	validation_1-logloss:0.01394
# [317]	validation_0-logloss:0.00667	validation_1-logloss:0.01391
# [318]	validation_0-logloss:0.00667	validation_1-logloss:0.01388
# [319]	validation_0-logloss:0.00666	validation_1-logloss:0.01381
# [320]	validation_0-logloss:0.00665	validation_1-logloss:0.01383
# [321]	validation_0-logloss:0.00664	validation_1-logloss:0.01382
# [322]	validation_0-logloss:0.00663	validation_1-logloss:0.01376
# [323]	validation_0-logloss:0.00663	validation_1-logloss:0.01373
# [324]	validation_0-logloss:0.00661	validation_1-logloss:0.01374
# [325]	validation_0-logloss:0.00661	validation_1-logloss:0.01370
# [326]	validation_0-logloss:0.00660	validation_1-logloss:0.01369
# [327]	validation_0-logloss:0.00659	validation_1-logloss:0.01366
# [328]	validation_0-logloss:0.00658	validation_1-logloss:0.01367
# [329]	validation_0-logloss:0.00657	validation_1-logloss:0.01361
# [330]	validation_0-logloss:0.00656	validation_1-logloss:0.01358
# [331]	validation_0-logloss:0.00655	validation_1-logloss:0.01358
# [332]	validation_0-logloss:0.00654	validation_1-logloss:0.01357
# [333]	validation_0-logloss:0.00654	validation_1-logloss:0.01351
# [334]	validation_0-logloss:0.00653	validation_1-logloss:0.01352
# [335]	validation_0-logloss:0.00652	validation_1-logloss:0.01351
# [336]	validation_0-logloss:0.00651	validation_1-logloss:0.01348
# [337]	validation_0-logloss:0.00650	validation_1-logloss:0.01349
# [338]	validation_0-logloss:0.00649	validation_1-logloss:0.01346
# [339]	validation_0-logloss:0.00648	validation_1-logloss:0.01343
# [340]	validation_0-logloss:0.00648	validation_1-logloss:0.01337
# [341]	validation_0-logloss:0.00647	validation_1-logloss:0.01338
# [342]	validation_0-logloss:0.00646	validation_1-logloss:0.01337
# [343]	validation_0-logloss:0.00645	validation_1-logloss:0.01337
# [344]	validation_0-logloss:0.00644	validation_1-logloss:0.01331
# [345]	validation_0-logloss:0.00644	validation_1-logloss:0.01328
# [346]	validation_0-logloss:0.00643	validation_1-logloss:0.01323
# [347]	validation_0-logloss:0.00642	validation_1-logloss:0.01321
# [348]	validation_0-logloss:0.00641	validation_1-logloss:0.01323
# [349]	validation_0-logloss:0.00640	validation_1-logloss:0.01322
# [350]	validation_0-logloss:0.00639	validation_1-logloss:0.01319
# [351]	validation_0-logloss:0.00639	validation_1-logloss:0.01316
# [352]	validation_0-logloss:0.00638	validation_1-logloss:0.01317
# [353]	validation_0-logloss:0.00637	validation_1-logloss:0.01315
# [354]	validation_0-logloss:0.00636	validation_1-logloss:0.01310
# [355]	validation_0-logloss:0.00636	validation_1-logloss:0.01307
# [356]	validation_0-logloss:0.00635	validation_1-logloss:0.01308
# [357]	validation_0-logloss:0.00634	validation_1-logloss:0.01309
# [358]	validation_0-logloss:0.00633	validation_1-logloss:0.01303
# [359]	validation_0-logloss:0.00632	validation_1-logloss:0.01302
# [360]	validation_0-logloss:0.00632	validation_1-logloss:0.01299
# [361]	validation_0-logloss:0.00631	validation_1-logloss:0.01293
# [362]	validation_0-logloss:0.00630	validation_1-logloss:0.01295
# [363]	validation_0-logloss:0.00629	validation_1-logloss:0.01292
# [364]	validation_0-logloss:0.00628	validation_1-logloss:0.01292
# [365]	validation_0-logloss:0.00627	validation_1-logloss:0.01293
# [366]	validation_0-logloss:0.00627	validation_1-logloss:0.01291
# [367]	validation_0-logloss:0.00626	validation_1-logloss:0.01288
# [368]	validation_0-logloss:0.00626	validation_1-logloss:0.01283
# [369]	validation_0-logloss:0.00625	validation_1-logloss:0.01280
# [370]	validation_0-logloss:0.00624	validation_1-logloss:0.01280
# [371]	validation_0-logloss:0.00623	validation_1-logloss:0.01279
# [372]	validation_0-logloss:0.00623	validation_1-logloss:0.01274
# [373]	validation_0-logloss:0.00622	validation_1-logloss:0.01275
# [374]	validation_0-logloss:0.00621	validation_1-logloss:0.01274
# [375]	validation_0-logloss:0.00620	validation_1-logloss:0.01271
# [376]	validation_0-logloss:0.00620	validation_1-logloss:0.01269
# [377]	validation_0-logloss:0.00619	validation_1-logloss:0.01270
# [378]	validation_0-logloss:0.00618	validation_1-logloss:0.01265
# [379]	validation_0-logloss:0.00617	validation_1-logloss:0.01263
# [380]	validation_0-logloss:0.00616	validation_1-logloss:0.01264
# [381]	validation_0-logloss:0.00616	validation_1-logloss:0.01258
# [382]	validation_0-logloss:0.00615	validation_1-logloss:0.01257
# [383]	validation_0-logloss:0.00615	validation_1-logloss:0.01254
# [384]	validation_0-logloss:0.00614	validation_1-logloss:0.01255
# [385]	validation_0-logloss:0.00613	validation_1-logloss:0.01253
# [386]	validation_0-logloss:0.00612	validation_1-logloss:0.01252
# [387]	validation_0-logloss:0.00611	validation_1-logloss:0.01253
# [388]	validation_0-logloss:0.00610	validation_1-logloss:0.01252
# [389]	validation_0-logloss:0.00610	validation_1-logloss:0.01247
# [390]	validation_0-logloss:0.00609	validation_1-logloss:0.01247
# [391]	validation_0-logloss:0.00609	validation_1-logloss:0.01244
# [392]	validation_0-logloss:0.00608	validation_1-logloss:0.01243
# [393]	validation_0-logloss:0.00607	validation_1-logloss:0.01238
# [394]	validation_0-logloss:0.00606	validation_1-logloss:0.01239
# [395]	validation_0-logloss:0.00606	validation_1-logloss:0.01239
# [396]	validation_0-logloss:0.00605	validation_1-logloss:0.01236
# [397]	validation_0-logloss:0.00604	validation_1-logloss:0.01237
# [398]	validation_0-logloss:0.00603	validation_1-logloss:0.01236
# [399]	validation_0-logloss:0.00602	validation_1-logloss:0.01236
# 오차 행렬
# [[34  3]
#  [ 1 76]]
# 정확도: 0.9649, 정밀도: 0.9620, 재현율: 0.9870,    F1: 0.9744, AUC:0.9954

# %%
from xgboost import plot_importance
import matplotlib.pyplot as plt
# %matplotlib inline

fig, ax = plt.subplots(figsize=(10, 12))
# 사이킷런 래퍼 클래스를 입력해도 무방. 
plot_importance(xgb_wrapper, ax=ax)
# Out:
# <Axes: title={'center': 'Feature importance'}, xlabel='F score', ylabel='Features'>
